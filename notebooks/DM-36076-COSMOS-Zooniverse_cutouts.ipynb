# %% [markdown]
# # DM-36076: Make Zooniverse cutouts for PST status talk, Sept. 2022
#
# * based on  DM-34711 HSC with fakes processing
# * no APDB available at present due to USDF migration
#
# * Repository is `/repo/main` and collection is `u/mrawls/DM-34711/hsc9813-fakes`
#
# * test on CI for now: `/sdf/home/e/ebellm/u/workspace/cosmos/repo` and collection `ap_verify-output`
#
# * Pipeline is in
# * BPS configuration file is in
# * Logs are in
# * APDB is in Postgres at  in schema `mrawls_DM34710_take2`.

# %%
# %matplotlib inline
#%matplotlib widget # interactive but doesn't persist


import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import importlib
import pandas as pd

from astropy.coordinates import SkyCoord
import astropy.units as u

import lsst.geom
import lsst.daf.butler as dafButler
from lsst.ap.association import UnpackApdbFlags, TransformDiaSourceCatalogConfig

sys.path.append('..')
import diaObjectAnalysis as doa
import apdbPlots as pla
import plotLightcurve as plc
import coaddAnalysis as coa
import seaborn as sns

# %%
sns.set_context('talk')

# %%
# Only if you change anything in the code imported above
importlib.reload(doa)
importlib.reload(pla)
importlib.reload(plc)
importlib.reload(coa)
# Out:
# <module 'coaddAnalysis' from '/sdf/data/rubin/u/ebellm/workspace/ap_pipe-notebooks/notebooks/../coaddAnalysis.py'>

# %%
repo = '/repo/main'
#repo = '/sdf/group/rubin/u/ebellm/workspace/cosmos/repo'
butler = dafButler.Butler(repo)

# %%
collection = 'u/mrawls/DM-34711/hsc9813-fakes'
#collection = 'ap_verify-output'

#dbSchema = 'mrawls_DM31053'
instrument = 'HSC'
skymap = 'hsc_rings_v1'

# %%
badFlagList = ['base_PixelFlags_flag_bad',
               'base_PixelFlags_flag_suspect',
               'base_PixelFlags_flag_saturatedCenter',
               'base_PixelFlags_flag_interpolated',
               'base_PixelFlags_flag_interpolatedCenter',
               'base_PixelFlags_flag_edge',
              ]

# %%
objTable, srcTable, goodObj, goodSrc = pla.loadTables(repo,
                                                      dbType='sqlite',
                                                      dbName='association.db',
                                                      isVerify=True,
                                                      schema=None,
                                                      gen='gen3',
                                                      instrument=instrument,
                                                      badFlagList=badFlagList)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 objTable, srcTable, goodObj, goodSrc = pla.loadTables(repo,
#       2                                                       dbType='sqlite',
#       3                                                       dbName='association.db',
#       4                                                       isVerify=True,
#       5                                                       schema=None,
#       6                                                       gen='gen3',
#       7                                                       instrument=instrument,
#       8                                                       badFlagList=badFlagList)
#
# File /sdf/data/rubin/u/ebellm/workspace/ap_pipe-notebooks/notebooks/../apdbPlots.py:440, in loadTables(repo, dbName, isVerify, dbType, badFlagList, instrument, gen, schema)
#     437 else:
#     438     butler = None
# --> 440 objTable = loadAllApdbObjects(dbPath, dbType=dbType, schema=schema)
#     441 srcTable = loadAllApdbSources(dbPath, dbType=dbType, schema=schema)
#     442 srcTable = addVisitCcdToSrcTable(srcTable, instrument=instrument, gen=gen, butler=butler)
#
# File /sdf/data/rubin/u/ebellm/workspace/ap_pipe-notebooks/notebooks/../diaObjectAnalysis.py:112, in loadAllApdbObjects(dbName, dbType, schema)
#      93 def loadAllApdbObjects(dbName, dbType='sqlite', schema=None):
#      94     """Load a subset of DIAObject columns from a APDB into a pandas dataframe.
#      95
#      96     Parameters
#    (...)
#     110         Columns selected are presently hard-wired here.
#     111     """
# --> 112     connection, tables = connectToApdb(dbName, dbType, schema)
#     114     # Only get objects with validityEnd NULL because that means they are still valid
#     115     objTable = pd.read_sql_query('select "diaObjectId", "ra", "decl", "nDiaSources", \
#     116                                   "gPSFluxMean", "rPSFluxMean", "iPSFluxMean", \
#     117                                   "zPSFluxMean", "yPSFluxMean", "validityEnd", "flags" from {0} \
#     118                                   where "validityEnd" is NULL;'.format(tables['obj']), connection)
#
# File /sdf/data/rubin/u/ebellm/workspace/ap_pipe-notebooks/notebooks/../diaObjectAnalysis.py:74, in connectToApdb(dbName, dbType, schema)
#      54 """Connect to an sqlite or postgres APDB.
#      55
#      56 Parameters
#    (...)
#      71     Hard-wired tables known to exist in the APDB
#      72 """
#      73 if dbType == 'sqlite':
# ---> 74     connection = sqlite3.connect(dbName)
#      75 elif dbType == 'postgres':
#      76     if schema is None:
#
# OperationalError: unable to open database file

# %%
#objTable, srcTable, goodObj, goodSrc = pla.loadTables(repo,
#                                                      dbType='postgres',
#                                                      dbName='lsstdevapdb1',
#                                                      schema=dbSchema,
#                                                      gen='gen3',
#                                                      instrument=instrument,
#                                                      badFlagList=badFlagList)

# %%
srcTable = pla.addVisitCcdToSrcTable(srcTable, instrument=instrument, gen='gen3', butler=butler)
flagTable, srcTableFlags, flagFilter, goodSrc, goodObj = pla.makeSrcTableFlags(srcTable, objTable,
                                                                               badFlagList=badFlagList,
                                                                               gen='gen3', instrument=instrument,
                                                                               repo=repo)

# %%
bandList = ['g', 'r', 'i', 'z', 'y']
colorList = ['C2', 'C1', 'C3', 'C5', 'k']

# %% [markdown]
# ## Access synthetic source information
#
# The `matchFakesTask` created one `fakes_goodSeeingDiff_matchDiaSrc` per visit and detector. It's a pandas dataframe, so we need to load them all up and create one with everything.

# %%
fakesMatchDiaSrc = butler.registry.queryDatasets(collections=collection,datasetType='fakes_goodSeeingDiff_matchDiaSrc')

# %%
#fakesMatchDiaSrc = butler.registry.queryDatasets(collections=collection,datasetType='fakes_deepDiff_matchDiaSrc')

# %%
len(list(fakesMatchDiaSrc))
# Out:
# 11721

# %%
# %%time
visitDetectorFrames = []

i = 0
maxi = 1000
#maxi = -1

for datasetRef in fakesMatchDiaSrc: 
    try:
        frame = butler.getDirect(datasetRef)
        
        # nondetected sources don't have DIASource records--so propagate metadata to all rows
        # grab a detected row
        w = frame['diaSourceId'] > 0
        if np.sum(w) == 0:
            print(f'No real sources detected in {datasetRef}')
            continue
        ccdVisitId = int(frame.loc[w,'ccdVisitId'].iloc[0])
        filterName = frame.loc[w,'filterName'].iloc[0]
        # propagate to all rows
        frame.loc[:,'ccdVisitId'] = ccdVisitId 
        frame.loc[:,'filterName'] = filterName 
    #except LookupError:
        #print(f'No data for {datasetRef}')
        #continue
    except Exception as e:
        #continue
        print(e)
        #raise(e)
    else:
        visitDetectorFrames.append(frame)
    i+=1
    if i == maxi:
        break

matchedDiaSources = pd.concat(visitDetectorFrames)

matchedDiaSources.loc[:,'ra'] = np.degrees(matchedDiaSources['ra_x'])
matchedDiaSources.loc[:,'decl'] = np.degrees(matchedDiaSources['dec'])
# Out:
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30488/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30488_1_07_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11732/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11732_1_18_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/324/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_324_1_53_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/344/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_344_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17926/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17926_1_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11738/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11738_0_00_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_0_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/322/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_322_1_07_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17926/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17926_0_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1184/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1184_0_01_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11722/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11722_1_30_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1208/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1208_1_26_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22608/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22608_0_38_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17934/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17934_0_33_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/362/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_362_0_35_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1248/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1248_0_15_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/350/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_350_0_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/352/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_352_0_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11718/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11718_0_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22642/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22642_0_26_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1182/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1182_1_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/326/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_326_0_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1168/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1168_1_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1180/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1180_1_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1880/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1880_0_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19684/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19684_1_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11726/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11726_0_00_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1870/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1870_0_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1246/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1246_1_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19684/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19684_1_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/348/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_348_0_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17948/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17948_1_20_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11728/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11728_1_54_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1220/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1220_0_09_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22642/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22642_0_04_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_0_22_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23706/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23706_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1170/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1170_0_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17930/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17930_1_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1218/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1218_1_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1208/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1208_1_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22644/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22644_0_07_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_0_07_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1188/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1188_1_33_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1182/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1182_0_00_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1194/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1194_0_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1230/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1230_1_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1176/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1176_1_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19684/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19684_0_56_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1172/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1172_0_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/358/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_358_0_43_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1218/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1218_0_47_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1172/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1172_1_32_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1244/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1244_0_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1168/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1168_0_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1168/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1168_0_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23692/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23692_1_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22646/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22646_0_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1208/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1208_0_05_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1190/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1190_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22664/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22664_0_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/360/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_360_1_00_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1202/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1202_1_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22664/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22664_0_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17948/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17948_1_08_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11738/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11738_1_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22660/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22660_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22660/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22660_1_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30488/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30488_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11732/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11732_0_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1220/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1220_0_11_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1874/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1874_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/318/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_318_1_27_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1204/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1204_0_17_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/344/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_344_0_42_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22646/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22646_1_09_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1202/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1202_0_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30496/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30496_0_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1174/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1174_0_20_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11724/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11724_1_42_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1230/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1230_1_09_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1206/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1206_0_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1214/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1214_0_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1188/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1188_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11732/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11732_0_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/358/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_358_1_05_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1220/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1220_0_26_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1230/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1230_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/352/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_352_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23694/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23694_0_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/324/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_324_0_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17930/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17930_0_47_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30488/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30488_1_22_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1186/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1186_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1872/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1872_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1244/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1244_0_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11740/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11740_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/318/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_318_0_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22646/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22646_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17950/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17950_0_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22606/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22606_1_17_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1202/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1202_0_47_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23706/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23706_0_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17902/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17902_0_54_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1868/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1868_1_30_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11720/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11720_0_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30484/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30484_1_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1168/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1168_0_07_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/358/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_358_1_01_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11726/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11726_0_17_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22608/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22608_0_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11734/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11734_0_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22644/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22644_1_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22648/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22648_1_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1232/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1232_0_28_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1868/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1868_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30496/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30496_0_32_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1216/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1216_1_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/332/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_332_0_22_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/356/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_356_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/324/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_324_0_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17962/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17962_1_30_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1168/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1168_1_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1206/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1206_0_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/330/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_330_0_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19710/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19710_0_38_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1190/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1190_1_33_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/354/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_354_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23704/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23704_1_56_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1242/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1242_0_17_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17948/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17948_1_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22642/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22642_0_22_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1194/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1194_1_28_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17908/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17908_1_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17908/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17908_1_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17948/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17948_1_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22606/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22606_0_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1182/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1182_0_12_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19708/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19708_0_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30502/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30502_0_05_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/360/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_360_0_54_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22628/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22628_1_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1194/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1194_0_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19660/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19660_1_18_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17950/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17950_0_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22664/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22664_0_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23706/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23706_1_39_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19708/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19708_0_34_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/350/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_350_1_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19694/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19694_0_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1210/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1210_0_15_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/344/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_344_1_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1194/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1194_0_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17906/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17906_0_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19708/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19708_1_28_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17932/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17932_1_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11734/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11734_0_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1178/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1178_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17944/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17944_0_01_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1228/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1228_1_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23694/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23694_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30486/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30486_1_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1166/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1166_1_42_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17900/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17900_0_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/332/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_332_1_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1166/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1166_1_00_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/352/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_352_0_11_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/332/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_332_1_35_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/362/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_362_0_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# ...
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1176/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1176_0_24_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17950/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17950_0_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23692/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23692_0_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23706/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23706_1_38_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/332/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_332_0_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/332/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_332_1_21_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1188/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1188_0_26_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17904/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17904_0_04_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1220/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1220_1_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140403/y/HSC-Y/1872/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_1872_1_06_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/348/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_348_1_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22604/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22604_0_40_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22662/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22662_1_02_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30502/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30502_1_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11738/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11738_0_32_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/358/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_358_1_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19710/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19710_1_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11740/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11740_1_10_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17900/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17900_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1174/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1174_1_14_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1190/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1190_1_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/358/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_358_0_44_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/z/HSC-Z/1194/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_1194_0_12_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30488/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30488_1_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1228/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1228_0_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150318/r/HSC-R/23704/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_23704_0_25_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1208/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1208_1_41_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1242/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1242_0_01_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/324/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_324_0_34_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30500/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30500_0_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22662/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22662_1_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30482/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30482_1_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150521/i/HSC-I/30484/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_30484_1_32_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22658/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22658_0_46_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150121/i/HSC-I/19694/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_19694_1_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17928/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17928_1_08_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17926/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17926_1_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22664/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22664_1_45_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11722/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11722_0_19_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/322/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_322_1_35_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1232/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1232_1_29_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22608/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22608_1_16_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/i/HSC-I/1238/fakes_goodSeeingDiff_matchDiaSrc_HSC_i_HSC-I_1238_1_36_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11720/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11720_1_23_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140328/r/HSC-R/1204/fakes_goodSeeingDiff_matchDiaSrc_HSC_r_HSC-R_1204_1_13_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20140325/y/HSC-Y/362/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_362_0_37_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150127/y/HSC-Y/22642/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_22642_1_03_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20150116/z/HSC-Z/17908/fakes_goodSeeingDiff_matchDiaSrc_HSC_z_HSC-Z_17908_0_08_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# [Errno 2] No such file or directory: '/sdf/group/rubin/repo/main/u/mrawls/DM-34711/hsc9813-fakes/20220726T202554Z/fakes_goodSeeingDiff_matchDiaSrc/20141118/y/HSC-Y/11732/fakes_goodSeeingDiff_matchDiaSrc_HSC_y_HSC-Y_11732_1_27_u_mrawls_DM-34711_hsc9813-fakes_20220726T202554Z.parq'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <timed exec>:35, in <module>
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/reshape/concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %%
matchedDiaSources
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 matchedDiaSources
#
# NameError: name 'matchedDiaSources' is not defined

# %%
matchedDiaSources.columns
# Out:
# Index(['fakeId', 'dec', 'ra_x', 'isVisitSource', 'isTemplateSource', 'u_mag',
#        'g_mag', 'r_mag', 'i_mag', 'z_mag', 'y_mag', 'disk_semimajor',
#        'bulge_semimajor', 'disk_n', 'bulge_n', 'disk_axis_ratio',
#        'bulge_axis_ratio', 'disk_pa', 'bulge_pa', 'sourceType', 'x_x', 'y_x',
#        'diaSourceId', 'ccdVisitId', 'filterName', 'diaObjectId', 'ssObjectId',
#        'parentDiaSourceId', 'midPointTai', 'bboxSize', 'flags', 'ra_y', 'decl',
#        'x_y', 'y_y', 'xErr', 'yErr', 'apFlux', 'apFluxErr', 'snr', 'psFlux',
#        'psFluxErr', 'psChi2', 'psNdata', 'trailFlux', 'trailRa', 'trailDecl',
#        'trailLength', 'trailAngle', 'dipMeanFlux', 'dipMeanFluxErr',
#        'dipFluxDiff', 'dipFluxDiffErr', 'dipLength', 'dipAngle', 'dipChi2',
#        'isDipole', 'totFlux', 'totFluxErr', 'ixx', 'iyy', 'ixy', 'ixxPSF',
#        'iyyPSF', 'ixyPSF', 'programId', 'ra'],
#       dtype='object')

# %%
np.sum(matchedDiaSources['diaSourceId'] > 0) /len(matchedDiaSources)
# Out:
# 0.9242424242424242

# %%
wScienceOnly = matchedDiaSources['isVisitSource'] & ~matchedDiaSources['isTemplateSource']
wMatched = matchedDiaSources['diaSourceId'] > 0

# %%
np.sum(wMatched & wScienceOnly) /np.sum(wScienceOnly)
# Out:
# 0.9166666666666666

# %%
# we need a spatial cut here.  spherical would be bettter
minra = matchedDiaSources.loc[wScienceOnly & wMatched,'ra'].min()
maxra = matchedDiaSources.loc[wScienceOnly & wMatched,'ra'].max()
mindecl = matchedDiaSources.loc[wScienceOnly & wMatched,'decl'].min()
maxdecl = matchedDiaSources.loc[wScienceOnly & wMatched,'decl'].max()

#wRADec = (matchedDiaSources.ra < 151.0 ) & (matchedDiaSources.ra > 149.4 ) & \
#           (matchedDiaSources.decl > 1.5 ) & (matchedDiaSources.decl < 2.9 )
wRADec = (matchedDiaSources.ra < maxra ) & (matchedDiaSources.ra > minra ) & \
           (matchedDiaSources.decl > mindecl ) & (matchedDiaSources.decl < maxdecl )

# %%
plt.figure()
plt.scatter(matchedDiaSources.loc[wScienceOnly & wMatched,'ra'],matchedDiaSources.loc[wScienceOnly & wMatched,'decl'],marker='x')
plt.scatter(matchedDiaSources.loc[wScienceOnly & ~wMatched,'ra'],matchedDiaSources.loc[wScienceOnly & ~wMatched,'decl'],marker='.')
plt.scatter(matchedDiaSources.loc[wScienceOnly & wRADec,'ra'],matchedDiaSources.loc[wScienceOnly & wRADec,'decl'],marker='+')

# %%
bins = np.linspace(20, 26, 70)
n_matched, edges = np.histogram(matchedDiaSources.loc[wMatched& wScienceOnly & wRADec,'g_mag'], bins=bins)
nmatched_err = np.sqrt(n_matched)

n_unmatched, edges = np.histogram(matchedDiaSources.loc[~wMatched & wScienceOnly & wRADec, 'g_mag'], bins=bins)
ntot = n_matched + n_unmatched
#print(n_matched, n_unmatched, ntot)
completeness_all = n_matched/ntot

# Attempt to compute some kind of error
ntot_err = np.sqrt(ntot) # compute on total to keep Poisson errors in gaussian regime
#print(ntot_err)
completeness_err_all = completeness_all * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)
# Out:
# /tmp/ipykernel_4953/112319062.py:8: RuntimeWarning: invalid value encountered in true_divide
#   completeness_all = n_matched/ntot
# /tmp/ipykernel_4953/112319062.py:13: RuntimeWarning: invalid value encountered in true_divide
#   completeness_err_all = completeness_all * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)

# %%
figure = plt.figure(figsize=(8,5))
plt.errorbar(bins[0:-1], completeness_all, completeness_err_all)
#plt.plot(bins[0:-1], completeness, marker='o', ms=5, ls=':')

plt.axhline(.9, ls='--', color='0.75', label='90%')
plt.xlabel('Injected g Magnitude')
plt.ylabel('Completeness')
#plt.ylim(0.7, 1.)
# Out:
# Text(0, 0.5, 'Completeness')

# %% [markdown]
# Now break this out by band

# %%
bins = np.linspace(20, 26, 70)

completeness_byband = {}
completeness_err_byband = {}

for band in bandList:
    wband = matchedDiaSources['filterName'] == band

    n_matched, edges = np.histogram(matchedDiaSources.loc[wMatched& wScienceOnly & wRADec & wband,f'{band}_mag'], bins=bins)
    nmatched_err = np.sqrt(n_matched)

    n_unmatched, edges = np.histogram(matchedDiaSources.loc[~wMatched & wScienceOnly & wRADec  & wband, f'{band}_mag'], bins=bins)
    ntot = n_matched + n_unmatched
    #print(n_matched, n_unmatched, ntot)
    completeness_byband[band] = n_matched/ntot

    # Attempt to compute some kind of error
    ntot_err = np.sqrt(ntot) # compute on total to keep Poisson errors in gaussian regime
    #print(ntot_err)
    completeness_err_byband[band] = completeness_byband[band] * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)
# Out:
# /tmp/ipykernel_4953/3647316630.py:15: RuntimeWarning: invalid value encountered in true_divide
#   completeness_byband[band] = n_matched/ntot
# /tmp/ipykernel_4953/3647316630.py:20: RuntimeWarning: invalid value encountered in true_divide
#   completeness_err_byband[band] = completeness_byband[band] * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)

# %%
fig, axs = plt.subplots(3, 2, figsize=(9, 12))

axG = axs[0, 0]
axR = axs[0, 1]
axI = axs[1, 0]
axZ = axs[1, 1]
axY = axs[2, 0]
#axHits = axs[2, 1]

ax0 = axs[2, 1]
ax0.axis('off')

axList = [axG, axR, axI, axZ, axY]
colorList = ['C2', 'C1', 'C3', 'C5', 'k']

xlim = (20,26)
ylim = (0, 1)
plt.setp(axs, xlim=xlim, ylim=ylim)

fig.suptitle(f'Completeness')


for ax, band, color in zip(axList, bandList, colorList):
    ax.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color)
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
plt.figure(figsize=(12, 12))

colorList = ['C2', 'C1', 'C3', 'C5', 'k']


for  band, color in zip( bandList, colorList):
    plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
plt.axhline(.9, ls='--', color='0.75', label='90%')
plt.legend(loc='lower left')
plt.xlabel('Injected magnitude')
plt.ylabel('Fractional completeness')
# Out:
# Text(0, 0.5, 'Fractional completeness')

# %% [markdown]
# ### estimate limiting magnitudes by band

# %% [markdown]
# To understand the completeness curves above (and to relate to our requirements), we need to understand what the limiting magnitude is for each ccdVisit.  We detect at 5 sigma and our requirements are at 6 sigma.  We can either compute limiting magnitudes empirically, using the observed SNR of our DIASource catalogs, or we can derive them from noise estimates.  Since we're trying to compare the fakes completeness to our expectations, we can't use the fakes themselves to define the limiting magnitudes.
#
# As of this writing it will take a bit of effort to estimate the limiting magnitude from the image properties directly (e.g., through noise  sky objects).  Instead, we will use the catalogued DIASources, and determine the flux (→ magnitude) of sources measured (not detected, since we don't have that information) at SNRs of 5 and 6.
# (Ideally we would only use non-fake DIASources--but that is somewhat of a hassle, so we're actually mixing real and fake DIASources in the analysis below.)
#
# Future improvements would include more rigorous exclusion of fakes, and attempts to derive the limiting magnitude instead from sky sources or the image noise itself.

# %%
# make a rough and ready estimate of the flux error
def estimate_fluxlim(flux, fluxerr, snr=5, snr_window_halfwidth=0.1):
    snr_all = np.abs(flux/fluxerr)
    wwindow = ((snr-snr_window_halfwidth) <= snr_all) & (snr_all <=  (snr+snr_window_halfwidth))
    if np.sum(wwindow) < 3:
        return np.nan
    return np.median(np.abs(flux.loc[wwindow]))
    
    
def estimate_maglim(flux, fluxerr, snr=5):
    fluxlim = estimate_fluxlim(flux, fluxerr, snr=snr)
    return (fluxlim * u.nJy).to(u.ABmag).value

# %%
estimate_fluxlim(goodSrc['psFlux'],goodSrc['psFluxErr'])
# Out:
# 130.73826664889506

# %%
estimate_maglim(goodSrc['psFlux'],goodSrc['psFluxErr'])
# Out:
# 26.10899319321281

# %% [markdown]
# For each CCDVisit, estimate the 5 and 6 sigma limiting magnitudes:

# %%
# a groupby didn't work since I'd need an aggregation function with multiple column inputs
maglims5 = {}
maglims6 = {}

for ccdVisitId, grp in goodSrc.groupby('ccdVisitId'):
    maglims5[ccdVisitId] = estimate_maglim(grp['psFlux'],grp['psFluxErr'],snr=5)
    maglims6[ccdVisitId] = estimate_maglim(grp['psFlux'],grp['psFluxErr'],snr=6)

# %%
lim5 = pd.Series(maglims5)
lim5.name = 'maglim5'
lim6 = pd.Series(maglims6)
lim6.name = 'maglim6'

dflim = pd.concat([lim5,lim6],axis=1)

# %% [markdown]
# Get the filterName for each CCDVisit:

# %%
filter_by_ccd = goodSrc.loc[goodSrc['diaSourceId'] > 0,['ccdVisitId','filterName']].groupby('ccdVisitId').agg(lambda x: np.unique(x)[0])
filter_by_ccd.name = 'filterName'
dflim = dflim.join(filter_by_ccd)

# %%
dflim = dflim.reset_index()
dflim.rename(columns={'index':'ccdVisitId'},inplace=True)
dflim
# Out:
#    ccdVisitId    maglim5    maglim6 filterName
# 0    11830050  26.020757        NaN          g
# 1    11832051        NaN  25.845396          g

# %%
plt.figure(figsize=(12,8))

for band, color in zip( bandList, colorList):
    plt.hist(dflim.loc[dflim['filterName'] == band,'maglim6'],color=color,histtype='step',label=band)
plt.legend()
plt.xlabel('Six-sigma limiting magnitude')
plt.ylabel('Number of CCD-visits')
# Out:
# Text(0, 0.5, 'Number of CCD-visits')

# %%
plt.figure(figsize=(12,8))

for band, color in zip( bandList, colorList):
    wband = goodSrc['filterName'] == band
    plt.errorbar(goodSrc.loc[wband,'snr'],
                 np.abs(goodSrc.loc[wband,'psFlux']),
                 goodSrc.loc[wband,'psFluxErr'],
                 color=color,label=band,linestyle='none',fmt='o')
plt.legend()
plt.xlabel('SNR')
plt.ylabel('abs(psFlux)')
plt.xlim(4,10)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
plt.scatter(pd.Series(maglims5).values,pd.Series(maglims6).values)

# %% [markdown]
# Determine the 25th and 75th percentile limiting magnitudes by filter:

# %%
p25_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,25))
median_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,50))
p75_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,75))

# %% [markdown]
# Plot per-filter completeness along with the limiting magnitudes and the required completeness:

# %%
plt.figure(figsize=(12, 12))

colorList = ['C2', 'C1', 'C3', 'C5', 'k']


for  band, color in zip( bandList, colorList):
    plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
    plt.axvline(median_limmag.loc[band,'maglim6'],color=color,ls=':')
    plt.axvspan(p25_limmag.loc[band,'maglim6'],p75_limmag.loc[band,'maglim6'],facecolor=color,alpha=0.2,edgecolor='none')

plt.axhline(.9, ls='--', color='0.75')#, label='90%')
plt.legend(loc='lower left')
plt.xlabel('Injected magnitude')
plt.ylabel('Fractional completeness')
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'r'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [97], in <cell line: 6>()
#       6 for  band, color in zip( bandList, colorList):
#       7     plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
# ----> 8     plt.axvline(median_limmag.loc[band,'maglim6'],color=color,ls=':')
#       9     plt.axvspan(p25_limmag.loc[band,'maglim6'],p75_limmag.loc[band,'maglim6'],facecolor=color,alpha=0.2,edgecolor='none')
#      11 plt.axhline(.9, ls='--', color='0.75')#, label='90%')
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'r'
# > /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py(3623)get_loc()
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
# ipdb>  q

# %% [markdown]
# So we are below the required 90% completeness level at 6 sigma in all bands: this need further investigation.  See DM-31388.
