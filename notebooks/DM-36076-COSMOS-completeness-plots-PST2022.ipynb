# %% [markdown]
# # DM-36076: Make COSMOS completeness plots for PST status talk, Sept. 2022
#
# * based on  DM-34711 HSC with fakes processing
# * no APDB available at present due to USDF migration
#
# * Repository is `/repo/main` and collection is `u/mrawls/DM-34711/hsc9813-fakes`
#
# * test on CI for now: `/sdf/home/e/ebellm/u/workspace/cosmos/repo` and collection `ap_verify-output`
#
# * Pipeline is in
# * BPS configuration file is in
# * Logs are in
# * APDB is in Postgres at  in schema `mrawls_DM34710_take2`.

# %%
#%matplotlib inline
# %matplotlib ipympl
#%matplotlib widget # interactive but doesn't persist


import os
import sys
import numpy as np
import matplotlib.pyplot as plt
import importlib
import pandas as pd

from astropy.coordinates import SkyCoord
import astropy.units as u

import lsst.geom
import lsst.daf.butler as dafButler
from lsst.ap.association import UnpackApdbFlags, TransformDiaSourceCatalogConfig

sys.path.append('..')
import diaObjectAnalysis as doa
import apdbPlots as pla
import plotLightcurve as plc
import coaddAnalysis as coa
import seaborn as sns
# Out:
# Overriding default configuration file with /opt/lsst/software/stack/stack/miniconda3-py38_4.9.2-4.1.0/Linux64/dustmaps_cachedata/g41a3ec361e+62d12e78cb/config/.dustmapsrc

# %%
sns.set_context('talk')

# %%
# Only if you change anything in the code imported above
importlib.reload(doa)
importlib.reload(pla)
importlib.reload(plc)
importlib.reload(coa)
# Out:
# <module 'coaddAnalysis' from '/sdf/data/rubin/u/ebellm/workspace/ap_pipe-notebooks/notebooks/../coaddAnalysis.py'>

# %%
repo = '/repo/main'
#repo = '/sdf/group/rubin/u/ebellm/workspace/cosmos/repo'
butler = dafButler.Butler(repo)

# %%
collection = 'u/mrawls/DM-34711/hsc9813-fakes'
#collection = 'ap_verify-output'

#dbSchema = 'mrawls_DM31053'
instrument = 'HSC'
skymap = 'hsc_rings_v1'

# %%
badFlagList = ['base_PixelFlags_flag_bad',
               'base_PixelFlags_flag_suspect',
               'base_PixelFlags_flag_saturatedCenter',
               'base_PixelFlags_flag_interpolated',
               'base_PixelFlags_flag_interpolatedCenter',
               'base_PixelFlags_flag_edge',
              ]

# %%
#objTable, srcTable, goodObj, goodSrc = pla.loadTables(repo,
#                                                      dbType='sqlite',
#                                                      dbName='association.db',
#                                                      isVerify=True,
#                                                      schema=None,
#                                                      gen='gen3',
#                                                      instrument=instrument,
#                                                      badFlagList=badFlagList)

# %%
#objTable, srcTable, goodObj, goodSrc = pla.loadTables(repo,
#                                                      dbType='postgres',
#                                                      dbName='lsstdevapdb1',
#                                                      schema=dbSchema,
#                                                      gen='gen3',
#                                                      instrument=instrument,
#                                                      badFlagList=badFlagList)

# %%
#srcTable = pla.addVisitCcdToSrcTable(srcTable, instrument=instrument, gen='gen3', butler=butler)
#flagTable, srcTableFlags, flagFilter, goodSrc, goodObj = pla.makeSrcTableFlags(srcTable, objTable,
#                                                                               badFlagList=badFlagList,
#                                                                               gen='gen3', instrument=instrument,
#                                                                               repo=repo)

# %%
bandList = ['g', 'r', 'i', 'z', 'y']
colorList = ['C2', 'C1', 'C3', 'C5', 'k']

# %% [markdown]
# ## Access synthetic source information
#
# The `matchFakesTask` created one `fakes_goodSeeingDiff_matchDiaSrc` per visit and detector. It's a pandas dataframe, so we need to load them all up and create one with everything.

# %%
fakesMatchDiaSrc = butler.registry.queryDatasets(collections=collection,datasetType='fakes_goodSeeingDiff_matchDiaSrc')

# %%
fsc = butler.registry.queryDatasets(collections=collection,datasetType='fakes_fakeSourceCat')

# %%
for datasetRef in fsc: 
    tmp = butler.getDirect(datasetRef)

# %%
tmp
# Out:
#                     fakeId       dec        ra  isVisitSource  \
# 0     12289303580519020549  0.053150  2.598143           True
# 1     13253914283861078471  0.049347  2.583746           True
# 2     10520709611904027360  0.044426  2.594133           True
# 3     10679126564681332766  0.068858  2.597333           True
# 4     12356400415495234647  0.059245  2.605577           True
# ...                    ...       ...       ...            ...
# 8858  12901914469599818326  0.049327  2.594695          False
# 8859   9419797189016685378  0.076670  2.611452          False
# 8860  12454114012034363250  0.045544  2.597897          False
# 8861  11497535112497752341  0.058836  2.597927          False
# 8862  13233807773644518696  0.083144  2.597028          False
#
#       isTemplateSource      u_mag      g_mag      r_mag      i_mag      z_mag  \
# 0                False  25.070739  25.070739  25.070739  25.070739  25.070739
# 1                False  22.608655  22.608655  22.608655  22.608655  22.608655
# 2                False  23.500343  23.500343  23.500343  23.500343  23.500343
# 3                False  23.080038  23.080038  23.080038  23.080038  23.080038
# 4                False  24.534644  24.534644  24.534644  24.534644  24.534644
# ...                ...        ...        ...        ...        ...        ...
# 8858              True  21.124361  21.124361  21.124361  21.124361  21.124361
# 8859              True  23.105277  23.105277  23.105277  23.105277  23.105277
# 8860              True  24.673663  24.673663  24.673663  24.673663  24.673663
# 8861              True  21.593862  21.593862  21.593862  21.593862  21.593862
# 8862              True  20.084868  20.084868  20.084868  20.084868  20.084868
#
#           y_mag  disk_semimajor  bulge_semimajor  disk_n  bulge_n  \
# 0     25.070739             1.0              1.0     1.0      1.0
# 1     22.608655             1.0              1.0     1.0      1.0
# 2     23.500343             1.0              1.0     1.0      1.0
# 3     23.080038             1.0              1.0     1.0      1.0
# 4     24.534644             1.0              1.0     1.0      1.0
# ...         ...             ...              ...     ...      ...
# 8858  21.124361             1.0              1.0     1.0      1.0
# 8859  23.105277             1.0              1.0     1.0      1.0
# 8860  24.673663             1.0              1.0     1.0      1.0
# 8861  21.593862             1.0              1.0     1.0      1.0
# 8862  20.084868             1.0              1.0     1.0      1.0
#
#       disk_axis_ratio  bulge_axis_ratio  disk_pa  bulge_pa sourceType
# 0                 1.0               1.0      0.0       1.0       star
# 1                 1.0               1.0      0.0       1.0       star
# 2                 1.0               1.0      0.0       1.0       star
# 3                 1.0               1.0      0.0       1.0       star
# 4                 1.0               1.0      0.0       1.0       star
# ...               ...               ...      ...       ...        ...
# 8858              1.0               1.0      0.0       1.0       star
# 8859              1.0               1.0      0.0       1.0       star
# 8860              1.0               1.0      0.0       1.0       star
# 8861              1.0               1.0      0.0       1.0       star
# 8862              1.0               1.0      0.0       1.0       star
#
# [8863 rows x 20 columns]

# %%
plt.scatter(tmp.ra,tmp.dec)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
list(butler.registry.queryDatasetTypes())
# Out:
# [DatasetType('skyMap', {skymap}, SkyMap),
#  DatasetType('raw', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('camera', {instrument}, Camera, isCalibration=True),
#  DatasetType('defects', {instrument, detector}, Defects, isCalibration=True),
#  DatasetType('bfKernel', {instrument}, NumpyArray, isCalibration=True),
#  DatasetType('transmission_optics', {instrument}, TransmissionCurve, isCalibration=True),
#  DatasetType('transmission_sensor', {instrument, detector}, TransmissionCurve, isCalibration=True),
#  DatasetType('transmission_filter', {band, instrument, physical_filter}, TransmissionCurve, isCalibration=True),
#  DatasetType('transmission_atmosphere', {instrument}, TransmissionCurve, isCalibration=True),
#  DatasetType('sky', {band, instrument, detector, physical_filter}, ExposureF, isCalibration=True),
#  DatasetType('bias', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('flat', {band, instrument, detector, physical_filter}, ExposureF, isCalibration=True),
#  DatasetType('dark', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('fringe', {band, instrument, detector, physical_filter}, ExposureF, isCalibration=True),
#  DatasetType('yBackground', {band, instrument, detector, physical_filter}, StrayLightData, isCalibration=True),
#  DatasetType('sdss_dr9_fink_v5b', {htm7}, SimpleCatalog),
#  DatasetType('ps1_pv3_3pi_20170110', {htm7}, SimpleCatalog),
#  DatasetType('gaia_dr2_20200414', {htm7}, SimpleCatalog),
#  DatasetType('brightObjectMask', {band, skymap, tract, patch}, ObjectMaskCatalog),
#  DatasetType('srcMatchFull', {band, instrument, detector, physical_filter, visit}, Catalog),
#  DatasetType('icSrc', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('sourceTable', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('src', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('source', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('srcMatch', {band, instrument, detector, physical_filter, visit}, Catalog),
#  DatasetType('skyCorr', {band, instrument, detector, physical_filter, visit}, Background),
#  DatasetType('calexp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('calexpBackground', {band, instrument, detector, physical_filter, visit}, Background),
#  DatasetType('src_schema', {}, SourceCatalog),
#  DatasetType('icSrc_schema', {}, SourceCatalog),
#  DatasetType('singleFrameDriver_config', {}, Config),
#  DatasetType('packages', {}, Packages),
#  DatasetType('skyCorr_config', {}, Config),
#  DatasetType('forced_src', {band, instrument, skymap, detector, physical_filter, tract, visit}, SourceCatalog),
#  DatasetType('jointcal_wcs', {band, instrument, skymap, detector, physical_filter, tract, visit}, Wcs),
#  DatasetType('fgcm_photoCalib', {band, instrument, detector, physical_filter, visit}, PhotoCalib),
#  DatasetType('transmission_atmosphere_fgcm', {band, instrument, physical_filter, visit}, TransmissionCurve),
#  DatasetType('deepCoadd_ref_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_mergeDet_schema', {}, SourceCatalog),
#  DatasetType('forced_src_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_deblendedFlux_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_forced_src_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_deblendedModel_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_meas_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_peak_schema', {}, PeakCatalog),
#  DatasetType('deepCoadd_det_schema', {}, SourceCatalog),
#  DatasetType('deepCoadd_mergeDet', {skymap, tract, patch}, SourceCatalog),
#  DatasetType('deepCoadd_obj', {skymap, tract, patch}, DataFrame),
#  DatasetType('deepCoadd_ref', {skymap, tract, patch}, SourceCatalog),
#  DatasetType('objectTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('objectTable_tract', {skymap, tract}, DataFrame),
#  DatasetType('deepCoadd_deblendedFlux', {band, skymap, tract, patch}, SourceCatalog),
#  DatasetType('deepCoadd_measMatchFull', {band, skymap, tract, patch}, Catalog),
#  DatasetType('deepCoadd_det', {band, skymap, tract, patch}, SourceCatalog),
#  DatasetType('deepCoadd_meas', {band, skymap, tract, patch}, SourceCatalog),
#  DatasetType('deepCoadd_forced_src', {band, skymap, tract, patch}, SourceCatalog),
#  DatasetType('deepCoadd_measMatch', {band, skymap, tract, patch}, Catalog),
#  DatasetType('deepCoadd_calexp_background', {band, skymap, tract, patch}, Background),
#  DatasetType('deepCoadd_calexp', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('deepCoadd', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('deepCoadd_psfMatchedWarp', {band, instrument, skymap, physical_filter, tract, patch, visit}, ExposureF),
#  DatasetType('deepCoadd_directWarp', {band, instrument, skymap, physical_filter, tract, patch, visit}, ExposureF),
#  DatasetType('deepCoadd_nImage', {band, skymap, tract, patch}, ImageU),
#  DatasetType('jointcal_config', {}, Config),
#  DatasetType('multiBandDriver_config', {}, Config),
#  DatasetType('forcedPhotCcd_config', {}, Config),
#  DatasetType('coaddDriver_config', {}, Config),
#  DatasetType('consolidateObjectTable_config', {}, Config),
#  DatasetType('writeObjectTable_config', {}, Config),
#  DatasetType('transformObjectCatalog_config', {}, Config),
#  DatasetType('matchVisits_config', {}, Config),
#  DatasetType('visitMatchTable', {band, skymap, tract}, DataFrame),
#  DatasetType('sourceTable_visit', {band, instrument, physical_filter, visit}, DataFrame),
#  DatasetType('fgcmLookUpTable', {instrument}, Catalog),
#  DatasetType('postISRCCD', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('isr_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('isr_config', {}, Config),
#  DatasetType('icExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('icExpBackground', {band, instrument, detector, physical_filter, visit}, Background),
#  DatasetType('characterizeImage_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('calibrate_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('writeSourceTable_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('transformSourceTable_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('consolidateSourceTable_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('characterizeImage_config', {}, Config),
#  DatasetType('calibrate_config', {}, Config),
#  DatasetType('writeSourceTable_config', {}, Config),
#  DatasetType('transformSourceTable_config', {}, Config),
#  DatasetType('consolidateSourceTable_config', {}, Config),
#  DatasetType('calexp_camera', {band, instrument, physical_filter, visit}, ImageF),
#  DatasetType('skyCorr_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('visitSummary', {band, instrument, physical_filter, visit}, ExposureCatalog),
#  DatasetType('consolidateVisitSummary_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('consolidateVisitSummary_config', {}, Config),
#  DatasetType('cpFlatProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpFlatNormScales', {band, instrument, physical_filter}, StructuredDataDict),
#  DatasetType('flatStats', {band, instrument, detector, physical_filter, exposure}, PropertyList),
#  DatasetType('cpFlatNorm_metadata', {band, instrument, physical_filter}, PropertySet),
#  DatasetType('cpFlatCombine_metadata', {band, instrument, detector, physical_filter}, PropertySet),
#  DatasetType('cpFlatMeasure_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('cpFlatNorm_config', {}, Config),
#  DatasetType('cpFlatCombine_config', {}, Config),
#  DatasetType('cpFlatMeasure_config', {}, Config),
#  DatasetType('cpCombine_metadata', {band, instrument, detector, physical_filter}, PropertySet),
#  DatasetType('cpCombine_config', {}, Config),
#  DatasetType('fgcmStarObservations', {instrument}, Catalog),
#  DatasetType('fgcmStarIndices', {instrument}, Catalog),
#  DatasetType('fgcmVisitCatalog', {instrument}, Catalog),
#  DatasetType('fgcmStarIds', {instrument}, Catalog),
#  DatasetType('fgcmReferenceStars', {instrument}, Catalog),
#  DatasetType('fgcmBuildStarsTable_metadata', {instrument}, PropertySet),
#  DatasetType('fgcmBuildStarsTable_config', {}, Config),
#  DatasetType('cpBiasProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpBiasCombine_metadata', {instrument, detector}, PropertySet),
#  DatasetType('cpBiasCombine_config', {}, Config),
#  DatasetType('cpDarkIsr', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpDarkProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpDark_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('cpDarkCombine_metadata', {instrument, detector}, PropertySet),
#  DatasetType('cpDark_config', {}, Config),
#  DatasetType('cpDarkCombine_config', {}, Config),
#  DatasetType('fgcmFitParameters0', {instrument}, Catalog),
#  DatasetType('fgcmFlaggedStars0', {instrument}, Catalog),
#  DatasetType('fgcmFitCycle_metadata', {instrument}, PropertySet),
#  DatasetType('fgcmFitCycle_config', {}, Config),
#  DatasetType('fgcmFitParameters1', {instrument}, Catalog),
#  DatasetType('fgcmFlaggedStars1', {instrument}, Catalog),
#  DatasetType('fgcmFitParameters2', {instrument}, Catalog),
#  DatasetType('fgcmFlaggedStars2', {instrument}, Catalog),
#  DatasetType('fgcmFlaggedStars3', {instrument}, Catalog),
#  DatasetType('fgcmFitParameters3', {instrument}, Catalog),
#  DatasetType('fgcmFitParameters4', {instrument}, Catalog),
#  DatasetType('fgcmFlaggedStars4', {instrument}, Catalog),
#  DatasetType('bestSeeingVisitsDict', {band, instrument, skymap, tract, patch}, StructuredDataDict),
#  DatasetType('measure_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('makeWarp_metadata', {band, instrument, skymap, physical_filter, tract, patch, visit}, PropertySet),
#  DatasetType('assembleCoadd_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('bestSeeingCoadd', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('bestSeeingCoadd_nImage', {band, skymap, tract, patch}, ImageU),
#  DatasetType('templateGen_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('mergeDetections_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('selectVisits_metadata', {band, instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('forcedPhotCoadd_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('detection_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('deblend_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('mergeMeasurements_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('writeObjectTable_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('transformObjectTable_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('consolidateObjectTable_metadata', {skymap, tract}, PropertySet),
#  DatasetType('measure_config', {}, Config),
#  DatasetType('makeWarp_config', {}, Config),
#  DatasetType('assembleCoadd_config', {}, Config),
#  DatasetType('templateGen_config', {}, Config),
#  DatasetType('mergeDetections_config', {}, Config),
#  DatasetType('selectVisits_config', {}, Config),
#  DatasetType('forcedPhotCoadd_config', {}, Config),
#  DatasetType('detection_config', {}, Config),
#  DatasetType('deblend_config', {}, Config),
#  DatasetType('mergeMeasurements_config', {}, Config),
#  DatasetType('transformObjectTable_config', {}, Config),
#  DatasetType('fgcmPhotoCalibCatalog', {band, instrument, physical_filter, visit}, ExposureCatalog),
#  DatasetType('fgcmOutputProducts_metadata', {instrument}, PropertySet),
#  DatasetType('fgcmOutputProducts_config', {}, Config),
#  DatasetType('fgcmStandardStars4', {instrument}, SimpleCatalog),
#  DatasetType('fgcmZeropoints4', {instrument}, Catalog),
#  DatasetType('fgcmAtmosphereParameters4', {instrument}, Catalog),
#  DatasetType('qe_curve', {instrument, detector}, QECurve, isCalibration=True),
#  DatasetType('cpDefectsProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpPartialDefects', {band, instrument, detector, physical_filter, exposure}, Defects),
#  DatasetType('measureDefects_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('mergeDefects_metadata', {instrument, detector}, PropertySet),
#  DatasetType('measureDefects_config', {}, Config),
#  DatasetType('mergeDefects_config', {}, Config),
#  DatasetType('cpPtcProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpCovariances', {band, instrument, detector, physical_filter, exposure}, PhotonTransferCurveDataset),
#  DatasetType('ptc', {instrument, detector}, PhotonTransferCurveDataset, isCalibration=True),
#  DatasetType('ptcSolve_metadata', {instrument, detector}, PropertySet),
#  DatasetType('ptcExtract_metadata', {instrument, detector}, PropertySet),
#  DatasetType('ptcSolve_config', {}, Config),
#  DatasetType('ptcExtract_config', {}, Config),
#  DatasetType('bfk', {instrument, detector}, BrighterFatterKernel, isCalibration=True),
#  DatasetType('bfkSolve_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('bfkSolve_config', {}, Config),
#  DatasetType('jointcalPhotoCalibCatalog', {band, instrument, skymap, physical_filter, tract, visit}, ExposureCatalog),
#  DatasetType('jointcalSkyWcsCatalog', {band, instrument, skymap, physical_filter, tract, visit}, ExposureCatalog),
#  DatasetType('jointcal_metadata', {band, instrument, skymap, physical_filter, tract}, PropertySet),
#  DatasetType('forcedPhotCcd_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit}, PropertySet),
#  DatasetType('deepCoadd_inputMap', {band, skymap, tract, patch}, HealSparseMap),
#  DatasetType('cpSkyIsr', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpSkyMaskedIsr', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpSkyDetectorBackground', {band, instrument, detector, physical_filter, exposure}, FocalPlaneBackground),
#  DatasetType('cpExpBackground', {band, instrument, detector, physical_filter, exposure}, Background),
#  DatasetType('cpSkyExpScale', {band, instrument, physical_filter, exposure}, PropertyList),
#  DatasetType('cpSkyExpBackground', {band, instrument, physical_filter, exposure}, FocalPlaneBackground),
#  DatasetType('cpSkyImage_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('cpSkySubtractBackground_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('cpSkyScaleMeasure_metadata', {band, instrument, physical_filter, exposure}, PropertySet),
#  DatasetType('skyCalib', {band, instrument, detector, physical_filter}, Exposure, isCalibration=True),
#  DatasetType('cpSkyCombine_metadata', {band, instrument, detector, physical_filter}, PropertySet),
#  DatasetType('cpSkyImage_config', {}, Config),
#  DatasetType('cpSkySubtractBackground_config', {}, Config),
#  DatasetType('cpSkyScaleMeasure_config', {}, Config),
#  DatasetType('cpSkyCombine_config', {}, Config),
#  DatasetType('deepCoadd_sky_noise_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_dra_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_e1_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_psf_e2_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_psf_size_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_psf_e1_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_psf_maglim_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_e2_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_ddec_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_exposure_time_map_sum', {band, skymap, tract}, HealSparseMap),
#  DatasetType('deepCoadd_sky_background_map_weighted_mean', {band, skymap, tract}, HealSparseMap),
#  DatasetType('HealSparsePropertyMapTask_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('HealSparsePropertyMapTask_config', {}, Config),
#  DatasetType('matchedCatalogTract', {band, instrument, skymap, tract}, SimpleCatalog),
#  DatasetType('matchedCatalogPatch', {band, instrument, skymap, tract, patch}, SimpleCatalog),
#  DatasetType('matchCatalogsPatch_metadata', {band, instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('matchCatalogsTract_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AM3', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AM3_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AD2_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AD2_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AM2', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AM2_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_PA1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('PA1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AF1_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AF1_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AF2_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AF2_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AM1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AM1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AD1_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AD1_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_info_AM1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AM1_info_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AD3_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AD3_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_AF3_design', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('AF3_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_PF1_design_gri', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('PF1_design_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('matchCatalogsPatch_config', {}, Config),
#  DatasetType('matchCatalogsTract_config', {}, Config),
#  DatasetType('AM3_config', {}, Config),
#  DatasetType('AD2_design_config', {}, Config),
#  DatasetType('AM2_config', {}, Config),
#  DatasetType('PA1_config', {}, Config),
#  DatasetType('AF1_design_config', {}, Config),
#  DatasetType('AF2_design_config', {}, Config),
#  DatasetType('AM1_config', {}, Config),
#  DatasetType('AD1_design_config', {}, Config),
#  DatasetType('AM1_info_config', {}, Config),
#  DatasetType('AD3_design_config', {}, Config),
#  DatasetType('AF3_design_config', {}, Config),
#  DatasetType('PF1_design_config', {}, Config),
#  DatasetType('cpCrosstalkProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('cpCrosstalkRatio', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('crosstalk', {instrument, detector}, CrosstalkCalib, isCalibration=True),
#  DatasetType('crosstalkSolve_metadata', {instrument, detector}, PropertySet),
#  DatasetType('crosstalkFluxes', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('crosstalkExtract_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('crosstalkSolve_config', {}, Config),
#  DatasetType('crosstalkExtract_config', {}, Config),
#  DatasetType('goodSeeingDiff_diaSrc_schema', {}, SourceCatalog),
#  DatasetType('forced_diff_schema', {}, SourceCatalog),
#  DatasetType('goodSeeingDiff_differenceExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('goodSeeingVisits', {band, instrument, skymap, tract, patch}, StructuredDataDict),
#  DatasetType('goodSeeingCoadd', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('goodSeeingDiff_diaSrc', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('goodSeeingDiff_warpedExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('imageDifference_metadata', {band, instrument, skymap, detector, physical_filter, visit}, PropertySet),
#  DatasetType('selectGoodSeeingVisits_metadata', {band, instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('forced_diff', {band, instrument, skymap, detector, physical_filter, tract, visit}, SourceCatalog),
#  DatasetType('forcedPhotDiffim_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit}, PropertySet),
#  DatasetType('goodSeeingCoadd_nImage', {band, skymap, tract, patch}, ImageU),
#  DatasetType('imageDifference_config', {}, Config),
#  DatasetType('selectGoodSeeingVisits_config', {}, Config),
#  DatasetType('forcedPhotDiffim_config', {}, Config),
#  DatasetType('nsrcMeasDetector_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasDetector', {band, instrument, detector, physical_filter, visit}, MetricValue),
#  DatasetType('nsrcMeasDetector_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('linearizer', {instrument, detector}, Linearizer, isCalibration=True),
#  DatasetType('matchedCatalogPatchMultiBand', {instrument, skymap, tract, patch}, SimpleCatalog),
#  DatasetType('metricvalue_validate_drp_AB1', {band, instrument, skymap, tract, patch}, MetricValue),
#  DatasetType('matchCatalogsPatchMultiBand_metadata', {instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('AB1_metadata', {band, instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('metricvalue_summary_validate_drp_AB1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('agg_summary_AB1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_TE1', {band, skymap, tract}, MetricValue),
#  DatasetType('TE1_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_TE2', {band, skymap, tract}, MetricValue),
#  DatasetType('TE2_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_pipe_analysis_wPerp', {skymap, tract}, MetricValue),
#  DatasetType('wPerp_metadata', {skymap, tract}, PropertySet),
#  DatasetType('matchCatalogsPatchMultiBand_config', {}, Config),
#  DatasetType('AB1_config', {}, Config),
#  DatasetType('agg_summary_AB1_config', {}, Config),
#  DatasetType('TE1_config', {}, Config),
#  DatasetType('TE2_config', {}, Config),
#  DatasetType('wPerp_config', {}, Config),
#  DatasetType('goodSeeingDiff_diaSrcTable', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('transformDiaSrcCat_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('transformDiaSrcCat_config', {}, Config),
#  DatasetType('overscanRaw', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('overscan_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('overscan_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeas', {band, instrument, skymap, tract, patch}, MetricValue),
#  DatasetType('nsrcMeas_metadata', {band, instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('metricvalue_Sum_info_nsrcMeas', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('agg_sum_nsrc_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('nsrcMeas_config', {}, Config),
#  DatasetType('agg_sum_nsrc_config', {}, Config),
#  DatasetType('skyPlot_PsfSn_sky', {skymap, tract}, Plot),
#  DatasetType('plot_PsfSn_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_GaussFlux_sky', {skymap, tract}, Plot),
#  DatasetType('plot_GaussFlux_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_PsfSn_goodCModel_sky', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_goodCmodel_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_PsfSn_goodCModel_gals_sky', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_goodCmodel_gals_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_PsfSn_high_sky', {skymap, tract}, Plot),
#  DatasetType('plot_PsfSn_highSN_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_KronDivPsf_sky', {skymap, tract}, Plot),
#  DatasetType('plot_KronDivPsf_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_PsfSn_sky_config', {}, Config),
#  DatasetType('plot_GaussFlux_sky_config', {}, Config),
#  DatasetType('plot_psfSn_goodCmodel_sky_config', {}, Config),
#  DatasetType('plot_psfSn_goodCmodel_gals_sky_config', {}, Config),
#  DatasetType('plot_PsfSn_highSN_sky_config', {}, Config),
#  DatasetType('plot_KronDivPsf_sky_config', {}, Config),
#  DatasetType('transformDiaSourceCat_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('transformDiaSourceCat_config', {}, Config),
#  DatasetType('DiaSrcTable', {band, instrument, physical_filter, visit}, DataFrame),
#  DatasetType('consolidateDiaSourceTable_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('consolidateDiaSourceTable_config', {}, Config),
#  DatasetType('skyPlot_CModelFlux_sky', {skymap, tract}, Plot),
#  DatasetType('visitTable', {instrument}, DataFrame),
#  DatasetType('makeVisitTable_metadata', {instrument}, PropertySet),
#  DatasetType('makeVisitTable_config', {}, Config),
#  DatasetType('apdb_marker', {band, instrument, detector, physical_filter, visit}, Config),
#  DatasetType('diaPipe_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('diaPipe_config', {}, Config),
#  DatasetType('CcdVisitTable', {instrument}, DataFrame),
#  DatasetType('makeCcdVisitTable_metadata', {instrument}, PropertySet),
#  DatasetType('makeCcdVisitTable_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_PsfSn_goodCModel_gals_sky', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_goodCmodel_gals_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_psfSn_goodCmodel_gals_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_PsfSn_goodCModel_stars_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_goodCmodel_stars_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_psfSn_goodCmodel_stars_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_PsfSn_goodCModel_all_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_goodCmodel_all_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_psfSn_goodCmodel_all_scatter_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasVisitTable', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('nsrcMeasVisitTable_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('nsrcMeasVisitTable_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_Blendedness_SN_stars', {skymap, tract}, Plot),
#  DatasetType('plot_blendedness_SN_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_blendedness_SN_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_iFWHM_SN_stars', {skymap, tract}, Plot),
#  DatasetType('plot_iFWHM_SN_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_iFWHM_SN_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_PsfSn_CModel_all_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_Cmodel_all_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('scatterTwoHistPlot_PsfSn_CModel_stars_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_psfSn_Cmodel_stars_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_psfSn_Cmodel_all_scatter_config', {}, Config),
#  DatasetType('plot_psfSn_Cmodel_stars_scatter_config', {}, Config),
#  DatasetType('photoCalibConsolidateGen2Gen3_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('photoCalibConsolidateGen2Gen3_config', {}, Config),
#  DatasetType('skyWcsConsolidateGen2Gen3_config', {}, Config),
#  DatasetType('skyWcsConsolidateGen2Gen3_2_config', {}, Config),
#  DatasetType('skyWcsConsolidateGen2Gen3_metadata', {band, instrument, skymap, physical_filter, tract, visit}, PropertySet),
#  DatasetType('atmospecCentroid', {band, instrument, detector, physical_filter, visit}, StructuredDataDict),
#  DatasetType('singleStarCentroidTask_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('singleStarCentroidTask_config', {}, Config),
#  DatasetType('verifyBiasProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('verifyBiasDetStats', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyBiasExpStats', {band, instrument, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyBiasApply_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyMeasureStats_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyExposureStats_metadata', {band, instrument, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyBiasStats', {instrument}, StructuredDataDict),
#  DatasetType('verifyRunStats_metadata', {instrument}, PropertySet),
#  DatasetType('verifyBiasApply_config', {}, Config),
#  DatasetType('verifyMeasureStats_config', {}, Config),
#  DatasetType('verifyExposureStats_config', {}, Config),
#  DatasetType('verifyRunStats_config', {}, Config),
#  DatasetType('healSparsePropertyMaps_config', {}, Config),
#  DatasetType('healSparsePropertyMaps_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('plot_HsmShapeRegauss_e1_sky_stars_config', {}, Config),
#  DatasetType('skyPlot_HsmShapeRegauss_e1_sky', {skymap, tract}, Plot),
#  DatasetType('plot_HsmShapeRegauss_e1_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_iHsmShapeRegauss_e1_sky', {skymap, tract}, Plot),
#  DatasetType('plot_HsmShapeRegauss_e2_meas_sky_stars_config', {}, Config),
#  DatasetType('plot_HsmShapeRegauss_e1_meas_sky_stars_config', {}, Config),
#  DatasetType('skyPlot_iHsmShapeRegauss_e2_meas_sky', {skymap, tract}, Plot),
#  DatasetType('plot_HsmShapeRegauss_e2_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_sky', {skymap, tract}, Plot),
#  DatasetType('plot_HsmShapeRegauss_e1_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_stars_config', {}, Config),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_gals_config', {}, Config),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_stars_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_gals_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_gals_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_stars_config', {}, Config),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_calib_psf_used_stars_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('processStarTask_config', {}, Config),
#  DatasetType('spectractorTestOutput', {band, instrument, detector, physical_filter, visit}, StructuredDataDict),
#  DatasetType('processStarTask_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('spectractorTestOutput2', {band, instrument, detector, physical_filter, visit}, NumpyArray),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_gals_config', {}, Config),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_calib_psf_used_gals_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_gals_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_PSFluxSN_meas_sky_all_config', {}, Config),
#  DatasetType('skyPlot_PSFluxSN_meas_all_sky', {skymap, tract}, Plot),
#  DatasetType('plot_PSFluxSN_meas_sky_all_metadata', {skymap, tract}, PropertySet),
#  DatasetType('processBrightStars_config', {}, Config),
#  DatasetType('brightStarStamps', {band, instrument, detector, physical_filter, visit}, BrightStarStamps),
#  DatasetType('processBrightStars_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('verifyDefectApply_config', {}, Config),
#  DatasetType('verifyDefectProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('verifyDefectExpStats', {band, instrument, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyDefectDetStats', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyDefectApply_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyDefectStats', {instrument}, StructuredDataDict),
#  DatasetType('TE3_config', {}, Config),
#  DatasetType('TE4_config', {}, Config),
#  DatasetType('nsrcMeasVisit_config', {}, Config),
#  DatasetType('agg_sum_nsrcVisit_config', {}, Config),
#  DatasetType('modelPhotRepStar1_config', {}, Config),
#  DatasetType('modelPhotRepStar3_config', {}, Config),
#  DatasetType('modelPhotRepGal4_config', {}, Config),
#  DatasetType('modelPhotRepGal2_config', {}, Config),
#  DatasetType('psfPhotRepStar3_config', {}, Config),
#  DatasetType('modelPhotRepStar2_config', {}, Config),
#  DatasetType('psfPhotRepStar2_config', {}, Config),
#  DatasetType('modelPhotRepGal1_config', {}, Config),
#  DatasetType('modelPhotRepGal3_config', {}, Config),
#  DatasetType('psfPhotRepStar4_config', {}, Config),
#  DatasetType('psfPhotRepStar1_config', {}, Config),
#  DatasetType('modelPhotRepStar4_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasVisit', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('metricvalue_validate_drp_TE3', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('TE3_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('metricvalue_validate_drp_TE4', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('TE4_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('nsrcMeasVisit_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('metricvalue_Sum_info_nsrcMeasVisit', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('agg_sum_nsrcVisit_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepStar1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepStar1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepStar3', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepStar3_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepGal4', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepGal4_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepGal2', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepGal2_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_psfPhotRepStar3', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('psfPhotRepStar3_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepStar2', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepStar2_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_psfPhotRepStar2', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('psfPhotRepStar2_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepGal1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepGal1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepGal3', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepGal3_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_psfPhotRepStar4', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('psfPhotRepStar4_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_psfPhotRepStar1', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('psfPhotRepStar1_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('metricvalue_validate_drp_modelPhotRepStar4', {band, instrument, skymap, tract}, MetricValue),
#  DatasetType('modelPhotRepStar4_metadata', {band, instrument, skymap, tract}, PropertySet),
#  DatasetType('drpAssociation_config', {}, Config),
#  DatasetType('drpDiaCalculation_config', {}, Config),
#  DatasetType('goodSeeingDiff_assocDiaSrcTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('goodSeeingDiff_diaObjTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('drpAssociation_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('diaSourceTable', {band, instrument, physical_filter, visit}, DataFrame),
#  DatasetType('goodSeeingDiff_fullDiaObjTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('drpDiaCalculation_metadata', {skymap, tract, patch}, PropertySet),
#  DatasetType('measureExtendedPsf_config', {}, Config),
#  DatasetType('extended_psf', {band}, ExtendedPsf),
#  DatasetType('measureExtendedPsf_metadata', {band, instrument}, PropertySet),
#  DatasetType('subtractBrightStars_config', {}, Config),
#  DatasetType('subtractedcalexp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('subtractBrightStars_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('preInterpISRCCD', {band, instrument, detector, physical_filter, exposure}, ExposureF),
#  DatasetType('verifyDarkApply_config', {}, Config),
#  DatasetType('verifyDarkExp_config', {}, Config),
#  DatasetType('verifyDarkChip_config', {}, Config),
#  DatasetType('verifyDark_config', {}, Config),
#  DatasetType('verifyDarkProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('verifyDarkExpStats', {band, instrument, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyDarkDetStats', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyDarkApply_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyDarkExp_metadata', {band, instrument, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyDarkChip_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyDarkStats', {instrument}, StructuredDataDict),
#  DatasetType('verifyDark_metadata', {instrument}, PropertySet),
#  DatasetType('nsrcMeasDetectorTable_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasDetectorTable', {band, instrument, detector, physical_filter, visit}, MetricValue),
#  DatasetType('nsrcMeasDetectorTable_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('verifyFlatApply_config', {}, Config),
#  DatasetType('verifyFlatChip_config', {}, Config),
#  DatasetType('verifyFlatExp_config', {}, Config),
#  DatasetType('verifyFlat_config', {}, Config),
#  DatasetType('verifyFlatProc', {band, instrument, detector, physical_filter, exposure}, Exposure),
#  DatasetType('verifyFlatDetStats', {band, instrument, detector, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyFlatExpStats', {band, instrument, physical_filter, exposure}, StructuredDataDict),
#  DatasetType('verifyFlatApply_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyFlatChip_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyFlatExp_metadata', {band, instrument, physical_filter, exposure}, PropertySet),
#  DatasetType('verifyFlatStats', {instrument}, StructuredDataDict),
#  DatasetType('verifyFlat_metadata', {instrument}, PropertySet),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_galaxies_config', {}, Config),
#  DatasetType('skyPlot_Kron_sub_PS_meas_galaxies_sky', {skymap, tract}, Plot),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_galaxies_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_stars_config', {}, Config),
#  DatasetType('skyPlot_Kron_sub_PS_meas_stars_sky', {skymap, tract}, Plot),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_unknown_config', {}, Config),
#  DatasetType('calibrate_log', {band, instrument, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('isr_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_stars_config', {}, Config),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_galaxies_config', {}, Config),
#  DatasetType('skyPlot_CircAp12_sub_PS_meas_calib_psf_used_unkowns_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_unknown_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_CModel_sub_PS_meas_stars_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('skyPlot_CModel_sub_PS_meas_galaxies_sky', {skymap, tract}, Plot),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_galaxies_metadata', {skymap, tract}, PropertySet),
#  DatasetType('subtracted_calexp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('brightStars_calexp_background', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('linearitySolve_config', {}, Config),
#  DatasetType('linearity', {instrument, detector}, Linearizer, isCalibration=True),
#  DatasetType('linearitySolve_metadata', {band, instrument, detector, physical_filter, exposure}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_CircAp12_sub_PS_meas_calib_psf_used_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_PsfTrace_sub_PSFHsmTraceDiff_meas_sky_stars_config', {}, Config),
#  DatasetType('skyPlot_PsfTrace_sub_HsmTraceDiff_meas_stars_sky', {skymap, tract}, Plot),
#  DatasetType('plot_PsfTrace_sub_PSFHsmTraceDiff_meas_sky_stars_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_skyObjects_sky_config', {}, Config),
#  DatasetType('skyPlot_skyObjects_sky', {skymap, tract}, Plot),
#  DatasetType('plot_skyObjects_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_scatter_config', {}, Config),
#  DatasetType('scatterTwoHistPlot_CircAp12_sub_PS_meas_scatter', {skymap, tract}, Plot),
#  DatasetType('plot_CircAp12_sub_PS_meas_scatter_metadata', {skymap, tract}, PropertySet),
#  DatasetType('fakes_goodSeeingDiff_diaSrc_schema', {}, SourceCatalog),
#  DatasetType('visitFakes_config', {}, Config),
#  DatasetType('matchFakes_config', {}, Config),
#  DatasetType('createFakes_config', {}, Config),
#  DatasetType('coaddFakes_config', {}, Config),
#  DatasetType('fracDiaSourcesToSciSources_config', {}, Config),
#  DatasetType('fakes_goodSeeingDiff_assocDiaSrc', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('fakes_calexp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('fakes_goodSeeingDiff_differenceExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('fakes_goodSeeingDiff_warpedExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('fakes_goodSeeingDiff_diaSrc', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('fakes_goodSeeingDiff_diaSrcTable', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('fakes_fakeSourceCat', {skymap, tract}, DataFrame),
#  DatasetType('fakes_goodSeeingCoadd', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('fakes_src', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('visitFakes_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit}, PropertySet),
#  DatasetType('fakes_goodSeeingDiff_matchDiaSrc', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('matchFakes_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit}, PropertySet),
#  DatasetType('createFakes_metadata', {skymap, tract}, PropertySet),
#  DatasetType('coaddFakes_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('metricvalue_ip_diffim_fracDiaSourcesToSciSources', {band, instrument, detector, physical_filter, visit}, MetricValue),
#  DatasetType('fracDiaSourcesToSciSources_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_scatter_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_galaxies_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_gals_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_galaxies_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_PSFluxSN_meas_sky_all_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CModel_sub_PSFmag_meas_sky_stars_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_stars_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_Kron_sub_PSFmag_meas_sky_stars_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_gals_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_calib_psf_used_sky_unknown_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_sky_stars_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_CircAp12_sub_PS_meas_scatter_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('deblend_log', {skymap, tract, patch}, ButlerLogRecords),
#  DatasetType('jointcal_log', {band, instrument, skymap, physical_filter, tract}, ButlerLogRecords),
#  DatasetType('photoCalibConsolidateGen2Gen3_log', {band, instrument, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('skyWcsConsolidateGen2Gen3_log', {band, instrument, skymap, physical_filter, tract, visit}, ButlerLogRecords),
#  DatasetType('getTemplate_config', {}, Config),
#  DatasetType('goodSeeingDiff_templateExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('getTemplate_metadata', {band, instrument, skymap, detector, physical_filter, visit}, PropertySet),
# ...
#  DatasetType('verifyBfkChip_config', {}, Config),
#  DatasetType('verifyBfkDetStats', {band, instrument, detector, physical_filter, visit}, StructuredDataDict),
#  DatasetType('verifyBfkChip_metadata', {band, instrument, detector, physical_filter, visit}, PropertySet),
#  DatasetType('verifyBfkChip_log', {band, instrument, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('middleSeeingDiff_diaSrc_schema', {}, SourceCatalog),
#  DatasetType('middleSeeingDiff_warpedExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('middleSeeingDiff_diaSrc', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('middleSeeingDiff_differenceExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('middleSeeingDiff_diaSrcTable', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('transformDiaSrcCat_log', {band, instrument, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('diaPipe_log', {band, instrument, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('cpSkyImage_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('cpSkySubtractBackground_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('cpSkyCombine_log', {band, instrument, detector, physical_filter}, ButlerLogRecords),
#  DatasetType('cpSkyScaleMeasure_log', {band, instrument, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('ConsolidateHealSparsePropertyMaps_config', {}, Config),
#  DatasetType('deepCoadd_dcr_dra_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_sky_background_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_e2_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_psf_size_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_ddec_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_psf_e1_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_dcr_e1_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_psf_e2_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_exposure_time_consolidated_map_sum', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_sky_noise_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('deepCoadd_psf_maglim_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('ConsolidateHealSparsePropertyMaps_metadata', {band, skymap}, PropertySet),
#  DatasetType('ConsolidateHealSparsePropertyMaps_log', {band, skymap}, ButlerLogRecords),
#  DatasetType('lsb_fakeSourceCat', {skymap, tract}, DataFrame),
#  DatasetType('plot_wFit_PSF_config', {}, Config),
#  DatasetType('colorColorFitPlot_deltaCoords', {skymap, tract}, Plot),
#  DatasetType('plot_wFit_PSF_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_wFit_PSF_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('coaddFakes_log', {band, skymap, tract, patch}, ButlerLogRecords),
#  DatasetType('fakes_goodSeeingDiff_templateExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('fracDiaSourcesToSciSources_log', {band, instrument, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('visitFakes_log', {band, instrument, skymap, detector, physical_filter, tract, visit}, ButlerLogRecords),
#  DatasetType('retrieveTemplate_metadata', {band, instrument, skymap, detector, physical_filter, visit}, PropertySet),
#  DatasetType('retrieveTemplate_log', {band, instrument, skymap, detector, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('createFakes_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('retrieveTemplate_config', {}, Config),
#  DatasetType('nsrcMeasTractMultiBandTable_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasTractMultiBandTable', {skymap, tract}, MetricValue),
#  DatasetType('nsrcMeasTractMultiBandTable_metadata', {skymap, tract}, PropertySet),
#  DatasetType('nsrcMeasTractMultiBandTable_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('bestThirdCoadd', {band, skymap, tract, patch}, ExposureF),
#  DatasetType('bestThirdCoadd_nImage', {band, skymap, tract, patch}, ImageU),
#  DatasetType('bestThirdDiff_diaSrc', {band, instrument, detector, physical_filter, visit}, SourceCatalog),
#  DatasetType('bestThirdDiff_warpedExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('bestThirdDiff_differenceExp', {band, instrument, detector, physical_filter, visit}, ExposureF),
#  DatasetType('bestThirdDiff_diaSrcTable', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('bestThirdDiff_diaSrc_schema', {}, SourceCatalog),
#  DatasetType('SkyObjectMean_config', {}, Config),
#  DatasetType('metricvalue_pipe_analysis_SkyObjectMean', {band, skymap, tract}, MetricValue),
#  DatasetType('SkyObjectMean_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('SkyObjectMean_log', {band, skymap, tract}, ButlerLogRecords),
#  DatasetType('SkyObjectMean0_config', {}, Config),
#  DatasetType('SkyObjectMean0_metadata', {band, skymap, tract}, PropertySet),
#  DatasetType('SkyObjectMean0_log', {band, skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_ri_gr_psf_config', {}, Config),
#  DatasetType('colorColorPlot_ri_gr_psf', {skymap, tract}, Plot),
#  DatasetType('plot_ri_gr_psf_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_ri_gr_psf_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('nsrcMeasPatchTable_config', {}, Config),
#  DatasetType('metricvalue_info_nsrcMeasPatchTable', {band, skymap, tract, patch}, MetricValue),
#  DatasetType('nsrcMeasPatchTable_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('nsrcMeasPatchTable_log', {band, skymap, tract, patch}, ButlerLogRecords),
#  DatasetType('overscan_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('verifyBfkExp_config', {}, Config),
#  DatasetType('verifyBfk_config', {}, Config),
#  DatasetType('verifyBfkExpStats', {band, instrument, physical_filter, visit}, StructuredDataDict),
#  DatasetType('verifyBfkExp_metadata', {band, instrument, physical_filter, visit}, PropertySet),
#  DatasetType('verifyBfkExp_log', {band, instrument, physical_filter, visit}, ButlerLogRecords),
#  DatasetType('verifyBfkStats', {instrument}, StructuredDataDict),
#  DatasetType('verifyBfk_metadata', {instrument}, PropertySet),
#  DatasetType('verifyBfk_log', {instrument}, ButlerLogRecords),
#  DatasetType('doubleHistogramPlot_skyObject_hist', {skymap, tract}, Plot),
#  DatasetType('plot_skyObject_sky_config', {}, Config),
#  DatasetType('plot_skyObject_hist_config', {}, Config),
#  DatasetType('skyPlot_skyObject_sky', {skymap, tract}, Plot),
#  DatasetType('plot_skyObject_sky_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_skyObject_sky_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('plot_skyObject_hist_metadata', {skymap, tract}, PropertySet),
#  DatasetType('plot_skyObject_hist_log', {skymap, tract}, ButlerLogRecords),
#  DatasetType('histPlot_skyObject_hist', {skymap, tract}, Plot),
#  DatasetType('verifyFlatApply_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('verifyFlatChip_log', {band, instrument, detector, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('verifyFlat_log', {instrument}, ButlerLogRecords),
#  DatasetType('verifyFlatExp_log', {band, instrument, physical_filter, exposure}, ButlerLogRecords),
#  DatasetType('eoBrighterFatter_config', {}, Config),
#  DatasetType('eoFlatLow_config', {}, Config),
#  DatasetType('eoReadNoise_config', {}, Config),
#  DatasetType('eoDark_config', {}, Config),
#  DatasetType('eoOverscan_config', {}, Config),
#  DatasetType('eoBias_config', {}, Config),
#  DatasetType('eoFlatHigh_config', {}, Config),
#  DatasetType('eoTearing_config', {}, Config),
#  DatasetType('eoBiasStability_config', {}, Config),
#  DatasetType('eoBrightPixels_config', {}, Config),
#  DatasetType('eoDefects_config', {}, Config),
#  DatasetType('eoDarkPixels_config', {}, Config),
#  DatasetType('eoDarkCurrent_config', {}, Config),
#  DatasetType('eoDark', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('eoBias', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('eoFlatHigh', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('eoBrightPixels', {instrument, detector}, Defects, isCalibration=True),
#  DatasetType('eoDefects', {instrument, detector}, Defects, isCalibration=True),
#  DatasetType('eoDarkPixels', {instrument, detector}, Defects, isCalibration=True),
#  DatasetType('eoBrighterFatter', {instrument, detector}, IsrCalib),
#  DatasetType('eoBrighterFatter_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoBrighterFatter_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoFlatLow', {instrument, detector}, ExposureF, isCalibration=True),
#  DatasetType('eoFlatLow_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoFlatLow_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoReadNoise', {instrument, detector}, IsrCalib),
#  DatasetType('eoReadNoise_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoReadNoise_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoDark_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoDark_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoOverscan', {instrument, detector}, IsrCalib),
#  DatasetType('eoOverscan_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoOverscan_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoBias_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoBias_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoFlatHigh_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoFlatHigh_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoTearing', {instrument, detector}, IsrCalib),
#  DatasetType('eoTearing_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoTearing_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoBiasStability', {instrument, detector}, IsrCalib),
#  DatasetType('eoBiasStability_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoBiasStability_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoBrightPixelStats', {instrument, detector}, IsrCalib),
#  DatasetType('eoBrightPixels_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoBrightPixels_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoDefects_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoDefects_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoDarkPixelStats', {instrument, detector}, IsrCalib),
#  DatasetType('eoDarkPixels_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoDarkPixels_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('eoDarkCurrent', {instrument, detector}, IsrCalib),
#  DatasetType('eoDarkCurrent_metadata', {instrument, detector}, PropertySet),
#  DatasetType('eoDarkCurrent_log', {instrument, detector}, ButlerLogRecords),
#  DatasetType('coaddsInCellsV1_config', {}, Config),
#  DatasetType('coaddsInCellsV1_metadata', {band, skymap, tract, patch}, PropertySet),
#  DatasetType('coaddsInCellsV1_log', {band, skymap, tract, patch}, ButlerLogRecords),
#  DatasetType('consolidateHealSparsePropertyMaps_config', {}, Config),
#  DatasetType('consolidateHealSparsePropertyMaps_metadata', {band, skymap}, PropertySet),
#  DatasetType('consolidateHealSparsePropertyMaps_log', {band, skymap}, ButlerLogRecords),
#  DatasetType('ccdVisitTable', {instrument}, DataFrame),
#  DatasetType('metricvalue_jointcal_astrometry_prepared_fittedStars', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_final_chi2', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_collected_refStars', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_matched_fittedStars', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_prepared_ccdImages', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_prepared_refStars', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_jointcal_astrometry_final_ndof', {band, instrument, skymap, physical_filter, tract}, MetricValue),
#  DatasetType('metricvalue_validate_drp_TE1_table', {band, skymap, tract}, MetricValue),
#  DatasetType('metricvalue_validate_drp_TE2_table', {band, skymap, tract}, MetricValue),
#  DatasetType('metricvalue_validate_drp_TE3_table', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('metricvalue_validate_drp_TE4_table', {band, instrument, physical_filter, visit}, MetricValue),
#  DatasetType('diaSourceTable_tract', {skymap, tract}, DataFrame),
#  DatasetType('diaObjectTable_tract', {skymap, tract}, DataFrame),
#  DatasetType('forcedSourceOnDiaObjectTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('consolidateFullDiaObjectTable_metadata', {instrument, skymap, tract}, PropertySet),
#  DatasetType('transformForcedSourceOnDiaObjectTable_metadata', {instrument, skymap, tract, patch}, PropertySet),
#  DatasetType('writeForcedSourceOnDiaObjectTable_log', {band, instrument, skymap, detector, physical_filter, tract, visit}, ButlerLogRecords),
#  DatasetType('transformForcedSourceOnDiaObjectTable_log', {instrument, skymap, tract, patch}, ButlerLogRecords),
#  DatasetType('consolidateAssocDiaSourceTable_metadata', {instrument, skymap, tract}, PropertySet),
#  DatasetType('writeForcedSourceOnDiaObjectTable_metadata', {band, instrument, skymap, detector, physical_filter, tract, visit}, PropertySet),
#  DatasetType('forcedSourceOnDiaObject', {band, instrument, detector, physical_filter, visit}, DataFrame),
#  DatasetType('consolidateAssocDiaSourceTable_config', {}, Config),
#  DatasetType('consolidateForcedSourceOnDiaObjectTable_log', {instrument, skymap, tract}, ButlerLogRecords),
#  DatasetType('transformForcedSourceOnDiaObjectTable_config', {}, Config),
#  DatasetType('consolidateAssocDiaSourceTable_log', {instrument, skymap, tract}, ButlerLogRecords),
#  DatasetType('forcedSourceOnDiaObjectTable_tract', {skymap, tract}, DataFrame),
#  DatasetType('consolidateFullDiaObjectTable_config', {}, Config),
#  DatasetType('consolidateForcedSourceOnDiaObjectTable_metadata', {instrument, skymap, tract}, PropertySet),
#  DatasetType('writeForcedSourceOnDiaObjectTable_config', {}, Config),
#  DatasetType('consolidateForcedSourceOnDiaObjectTable_config', {}, Config),
#  DatasetType('consolidateFullDiaObjectTable_log', {instrument, skymap, tract}, ButlerLogRecords),
#  DatasetType('forcedSourceTable_tract', {skymap, tract}, DataFrame),
#  DatasetType('forcedSourceTable', {skymap, tract, patch}, DataFrame),
#  DatasetType('quickLookExp', {band, instrument, detector, physical_filter, exposure}, ExposureF),
#  DatasetType('fakes_deepCoadd_dcr_dra_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('fakes_deepCoadd_psf_size_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('fakes_deepCoadd_dcr_e2_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('fakes_deepCoadd_sky_background_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('fakes_deepCoadd_psf_e2_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  DatasetType('fakes_deepCoadd_psf_e1_consolidated_map_weighted_mean', {band, skymap}, HealSparseMap),
#  ...]

# %%
#fakesMatchDiaSrc = butler.registry.queryDatasets(collections=collection,datasetType='fakes_deepDiff_matchDiaSrc')

# %%
len(list(fakesMatchDiaSrc))
# Out:
# 11721

# %%
# %%timfakesMatchDiaSrcitDetectorFrames = []
#
# i = 0
# maxi = 1000
# #maxi = -1
#
# for datasetRef in fakesMatchDiaSrc:
#     try:
#         frame = butler.getDirect(datasetRef)
#
#         # nondetected sources don't have DIASource records--so propagate metadata to all rows
#         # grab a detected row
#         w = frame['diaSourceId'] > 0
#         if np.sum(w) == 0:
#             print(f'No real sources detected in {datasetRef}')
#             continue
#         ccdVisitId = int(frame.loc[w,'ccdVisitId'].iloc[0])
#         filterName = frame.loc[w,'filterName'].iloc[0]
#         # propagate to all rows
#         frame.loc[:,'ccdVisitId'] = ccdVisitId
#         frame.loc[:,'filterName'] = filterName
#     #except LookupError:
#         #print(f'No data for {datasetRef}')
#         #continue
#     except Exception as e:
#         raise(e)
#     else:
#         visitDetectorFrames.append(frame)
#     i+=1
#     if i == maxi:
#         break
#
# matchedDiaSources = pd.concat(visitDetectorFrames)
#
# matchedDiaSources.loc[:,'ra'] = np.degrees(matchedDiaSources['ra_x'])
# matchedDiaSources.loc[:,'decl'] = np.degrees(matchedDiaSources['dec'])
# Out:
# CPU times: user 10.7 s, sys: 3.19 s, total: 13.9 s
# Wall time: 1min

# %%
matchedDiaSources
# Out:
#                   fakeId       dec      ra_x  isVisitSource  isTemplateSource  \
# 0   11145333034679453063  0.034968  2.606775           True             False
# 1   10017336918725887089  0.034261  2.606984           True             False
# 2   11972332570614296022  0.034972  2.604728           True             False
# 3   13338769938538776059  0.035274  2.605133           True             False
# 4   11720169727824378976  0.034317  2.606557           True             False
# ..                   ...       ...       ...            ...               ...
# 27  12654163749490939312  0.043989  2.611948          False              True
# 28  13420030529907741240  0.043836  2.611339          False              True
# 29  11814407724769271335  0.042693  2.610111          False              True
# 30  11388569768728215781  0.044006  2.611231          False              True
# 31   9543190124636951715  0.043717  2.610436          False              True
#
#         u_mag      g_mag      r_mag      i_mag      z_mag  ...  isDipole  \
# 0   22.365355  22.365355  22.365355  22.214484  22.365355  ...     False
# 1   24.373904  24.373904  24.373904  24.143426  24.373904  ...     False
# 2   24.677834  24.677834  24.677834  24.903452  24.677834  ...      None
# 3   24.304241  24.304241  24.304241  22.946839  24.304241  ...      None
# 4   25.927183  25.927183  25.927183  25.357403  25.927183  ...      None
# ..        ...        ...        ...        ...        ...  ...       ...
# 27  23.085138  23.085138  23.085138  23.085138  23.085138  ...     False
# 28  20.276287  20.276287  20.276287  20.276287  20.276287  ...     False
# 29  23.408272  23.408272  23.408272  23.408272  23.408272  ...      None
# 30  23.166615  23.166615  23.166615  23.166615  23.166615  ...     False
# 31  20.013189  20.013189  20.013189  20.013189  20.013189  ...     False
#
#         totFlux  totFluxErr       ixx       iyy       ixy    ixxPSF    iyyPSF  \
# 0   4762.978323   50.387989  0.059046  0.088130  0.010774  0.059817  0.008025
# 1    721.289988   49.682014  0.061016  0.078651  0.004489  0.060434  0.008108
# 2           NaN         NaN       NaN       NaN       NaN       NaN       NaN
# 3           NaN         NaN       NaN       NaN       NaN       NaN       NaN
# 4           NaN         NaN       NaN       NaN       NaN       NaN       NaN
# ..          ...         ...       ...       ...       ...       ...       ...
# 27  -339.608373  233.902161       NaN       NaN       NaN  0.077844 -0.007955
# 28   314.164922  232.041441       NaN       NaN       NaN  0.076900 -0.007858
# 29          NaN         NaN       NaN       NaN       NaN       NaN       NaN
# 30   -71.562834  232.477507       NaN       NaN       NaN  0.076540 -0.007822
# 31  -246.806782  245.203612       NaN       NaN       NaN  0.075240 -0.007689
#
#       ixyPSF          ra
# 0   0.008025  149.357229
# 1   0.008108  149.369155
# 2        NaN  149.239907
# 3        NaN  149.263110
# 4        NaN  149.344687
# ..       ...         ...
# 27 -0.007955  149.653600
# 28 -0.007858  149.618702
# 29       NaN  149.548337
# 30 -0.007822  149.612499
# 31 -0.007689  149.566948
#
# [35255 rows x 66 columns]

# %%
matchedDiaSources.columns
# Out:
# Index(['fakeId', 'dec', 'ra_x', 'isVisitSource', 'isTemplateSource', 'u_mag',
#        'g_mag', 'r_mag', 'i_mag', 'z_mag', 'y_mag', 'disk_semimajor',
#        'bulge_semimajor', 'disk_n', 'bulge_n', 'disk_axis_ratio',
#        'bulge_axis_ratio', 'disk_pa', 'bulge_pa', 'sourceType', 'x_x', 'y_x',
#        'diaSourceId', 'ccdVisitId', 'filterName', 'diaObjectId', 'ssObjectId',
#        'parentDiaSourceId', 'midPointTai', 'bboxSize', 'flags', 'ra_y', 'decl',
#        'x_y', 'y_y', 'xErr', 'yErr', 'apFlux', 'apFluxErr', 'snr', 'psFlux',
#        'psFluxErr', 'psChi2', 'psNdata', 'trailFlux', 'trailRa', 'trailDecl',
#        'trailLength', 'trailAngle', 'dipMeanFlux', 'dipMeanFluxErr',
#        'dipFluxDiff', 'dipFluxDiffErr', 'dipLength', 'dipAngle', 'dipChi2',
#        'isDipole', 'totFlux', 'totFluxErr', 'ixx', 'iyy', 'ixy', 'ixxPSF',
#        'iyyPSF', 'ixyPSF', 'ra'],
#       dtype='object')

# %%
np.sum(matchedDiaSources['diaSourceId'] > 0) /len(matchedDiaSources)
# Out:
# 0.6800453836335272

# %%
wScienceOnly = matchedDiaSources['isVisitSource'] & ~matchedDiaSources['isTemplateSource']
wMatched = matchedDiaSources['diaSourceId'] > 0

# %%
np.sum(wMatched & wScienceOnly) /np.sum(wScienceOnly)
# Out:
# 0.7006076438185019

# %%
# we need a spatial cut here.  spherical would be bettter
minra = matchedDiaSources.loc[wScienceOnly & wMatched,'ra'].min()
maxra = matchedDiaSources.loc[wScienceOnly & wMatched,'ra'].max()
mindecl = matchedDiaSources.loc[wScienceOnly & wMatched,'decl'].min()
maxdecl = matchedDiaSources.loc[wScienceOnly & wMatched,'decl'].max()

#wRADec = (matchedDiaSources.ra < 151.0 ) & (matchedDiaSources.ra > 149.4 ) & \
#           (matchedDiaSources.decl > 1.5 ) & (matchedDiaSources.decl < 2.9 )
wRADec = (matchedDiaSources.ra < maxra ) & (matchedDiaSources.ra > minra ) & \
           (matchedDiaSources.decl > mindecl ) & (matchedDiaSources.decl < maxdecl )

# %%
plt.figure()
plt.scatter(matchedDiaSources.loc[wScienceOnly & wMatched,'ra'],matchedDiaSources.loc[wScienceOnly & wMatched,'decl'],marker='x')
plt.scatter(matchedDiaSources.loc[wScienceOnly & ~wMatched,'ra'],matchedDiaSources.loc[wScienceOnly & ~wMatched,'decl'],marker='.')
plt.scatter(matchedDiaSources.loc[wScienceOnly & wRADec,'ra'],matchedDiaSources.loc[wScienceOnly & wRADec,'decl'],marker='+')

# %%
bins = np.linspace(20, 26, 70)
n_matched, edges = np.histogram(matchedDiaSources.loc[wMatched& wScienceOnly & wRADec,'g_mag'], bins=bins)
nmatched_err = np.sqrt(n_matched)

n_unmatched, edges = np.histogram(matchedDiaSources.loc[~wMatched & wScienceOnly & wRADec, 'g_mag'], bins=bins)
ntot = n_matched + n_unmatched
#print(n_matched, n_unmatched, ntot)
completeness_all = n_matched/ntot

# Attempt to compute some kind of error
ntot_err = np.sqrt(ntot) # compute on total to keep Poisson errors in gaussian regime
#print(ntot_err)
completeness_err_all = completeness_all * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)

# %%
figure = plt.figure(figsize=(8,5))
plt.errorbar(bins[0:-1], completeness_all, completeness_err_all)
#plt.plot(bins[0:-1], completeness, marker='o', ms=5, ls=':')

plt.axhline(.9, ls='--', color='0.75', label='90%')
plt.xlabel('Injected g Magnitude')
plt.ylabel('Completeness')
#plt.ylim(0.7, 1.)
# Out:
# Text(0, 0.5, 'Completeness')

# %% [markdown]
# Now break this out by band

# %%
bins = np.linspace(20, 26, 70)

completeness_byband = {}
completeness_err_byband = {}

for band in bandList:
    wband = matchedDiaSources['filterName'] == band

    n_matched, edges = np.histogram(matchedDiaSources.loc[wMatched& wScienceOnly & wRADec & wband,f'{band}_mag'], bins=bins)
    nmatched_err = np.sqrt(n_matched)

    n_unmatched, edges = np.histogram(matchedDiaSources.loc[~wMatched & wScienceOnly & wRADec  & wband, f'{band}_mag'], bins=bins)
    ntot = n_matched + n_unmatched
    #print(n_matched, n_unmatched, ntot)
    completeness_byband[band] = n_matched/ntot

    # Attempt to compute some kind of error
    ntot_err = np.sqrt(ntot) # compute on total to keep Poisson errors in gaussian regime
    #print(ntot_err)
    completeness_err_byband[band] = completeness_byband[band] * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)
# Out:
# /tmp/ipykernel_9357/3647316630.py:15: RuntimeWarning: invalid value encountered in true_divide
#   completeness_byband[band] = n_matched/ntot
# /tmp/ipykernel_9357/3647316630.py:20: RuntimeWarning: invalid value encountered in true_divide
#   completeness_err_byband[band] = completeness_byband[band] * np.sqrt((nmatched_err/n_matched)**2. + (ntot_err/ntot)**2.)

# %%
fig, axs = plt.subplots(3, 2, figsize=(9, 12))

axG = axs[0, 0]
axR = axs[0, 1]
axI = axs[1, 0]
axZ = axs[1, 1]
axY = axs[2, 0]
#axHits = axs[2, 1]

ax0 = axs[2, 1]
ax0.axis('off')

axList = [axG, axR, axI, axZ, axY]
colorList = ['C2', 'C1', 'C3', 'C5', 'k']

xlim = (20,26)
ylim = (0, 1)
plt.setp(axs, xlim=xlim, ylim=ylim)

fig.suptitle(f'Completeness')


for ax, band, color in zip(axList, bandList, colorList):
    ax.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color)
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)

# %%
plt.figure(figsize=(12, 12))

colorList = ['C2', 'C1', 'C3', 'C5', 'k']


for  band, color in zip( bandList, colorList):
    plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
plt.axhline(.9, ls='--', color='0.75', label='90%')
plt.legend(loc='lower left')
plt.xlabel('Injected magnitude')
plt.ylabel('Fractional completeness')
# Out:
# Text(0, 0.5, 'Fractional completeness')

# %% [markdown]
# ### estimate limiting magnitudes by band

# %% [markdown]
# To understand the completeness curves above (and to relate to our requirements), we need to understand what the limiting magnitude is for each ccdVisit.  We detect at 5 sigma and our requirements are at 6 sigma.  We can either compute limiting magnitudes empirically, using the observed SNR of our DIASource catalogs, or we can derive them from noise estimates.  Since we're trying to compare the fakes completeness to our expectations, we can't use the fakes themselves to define the limiting magnitudes.
#
# As of this writing it will take a bit of effort to estimate the limiting magnitude from the image properties directly (e.g., through noise  sky objects).  Instead, we will use the catalogued DIASources, and determine the flux (→ magnitude) of sources measured (not detected, since we don't have that information) at SNRs of 5 and 6.
# (Ideally we would only use non-fake DIASources--but that is somewhat of a hassle, so we're actually mixing real and fake DIASources in the analysis below.)
#
# Future improvements would include more rigorous exclusion of fakes, and attempts to derive the limiting magnitude instead from sky sources or the image noise itself.

# %%
# make a rough and ready estimate of the flux error
def estimate_fluxlim(flux, fluxerr, snr=5, snr_window_halfwidth=0.1):
    snr_all = np.abs(flux/fluxerr)
    wwindow = ((snr-snr_window_halfwidth) <= snr_all) & (snr_all <=  (snr+snr_window_halfwidth))
    if np.sum(wwindow) < 3:
        return np.nan
    return np.median(np.abs(flux.loc[wwindow]))
    
    
def estimate_maglim(flux, fluxerr, snr=5):
    fluxlim = estimate_fluxlim(flux, fluxerr, snr=snr)
    return (fluxlim * u.nJy).to(u.ABmag).value

# %%
# ideally we wouldn't use the matched DIASources for this but I'm not willing to concat all the catalogs
estimate_fluxlim(matchedDiaSources['psFlux'],matchedDiaSources['psFluxErr'])
#estimate_fluxlim(goodSrc['psFlux'],goodSrc['psFluxErr'])
# Out:
# 788.0635123425278

# %%
plt.figure()
_=plt.hist(np.abs(matchedDiaSources['psFlux']/matchedDiaSources['psFluxErr']),
                     histtype='step',label='PSF Flux SNR',

         bins=np.linspace(4,10,100))
_=plt.hist(matchedDiaSources['snr'],
                     histtype='step',label='Detection SNR',

         bins=np.linspace(4,10,100))
plt.legend()

# %%
estimate_maglim(matchedDiaSources['psFlux'],matchedDiaSources['psFluxErr'])
# Out:
# 24.158596950094754

# %% [markdown]
# For each CCDVisit, estimate the 5 and 6 sigma limiting magnitudes:

# %%
# a groupby didn't work since I'd need an aggregation function with multiple column inputs
maglims5 = {}
maglims6 = {}

for ccdVisitId, grp in matchedDiaSources.groupby('ccdVisitId'):
    maglims5[ccdVisitId] = estimate_maglim(grp['psFlux'],grp['psFluxErr'],snr=5)
    maglims6[ccdVisitId] = estimate_maglim(grp['psFlux'],grp['psFluxErr'],snr=6)

# %%
estimate_fluxlim(grp['psFlux'],grp['psFluxErr'],snr=6, snr_window_halfwidth=0.5)
# Out:
# nan

# %%
lim5 = pd.Series(maglims5)
lim5.name = 'maglim5'
lim6 = pd.Series(maglims6)
lim6.name = 'maglim6'

dflim = pd.concat([lim5,lim6],axis=1)

# %% [markdown]
# Get the filterName for each CCDVisit:

# %%
filter_by_ccd = matchedDiaSources.loc[matchedDiaSources['diaSourceId'] > 0,['ccdVisitId','filterName']].groupby('ccdVisitId').agg(lambda x: np.unique(x)[0])
filter_by_ccd.name = 'filterName'
dflim = dflim.join(filter_by_ccd)

# %%
dflim = dflim.reset_index()
dflim.rename(columns={'index':'ccdVisitId'},inplace=True)
dflim
# Out:
#      ccdVisitId  maglim5  maglim6 filterName
# 0         63604      NaN      NaN          y
# 1         63614      NaN      NaN          y
# 2         63617      NaN      NaN          y
# 3         63646      NaN      NaN          y
# 4         63657      NaN      NaN          y
# ..          ...      ...      ...        ...
# 995     6100812      NaN      NaN          i
# 996     6100848      NaN      NaN          i
# 997     6100875      NaN      NaN          i
# 998     6100884      NaN      NaN          i
# 999     6100892      NaN      NaN          i
#
# [1000 rows x 4 columns]

# %%
plt.figure(figsize=(12,8))

for band, color in zip( bandList, colorList):
    plt.hist(dflim.loc[dflim['filterName'] == band,'maglim6'],color=color,histtype='step',label=band)
plt.legend()
plt.xlabel('Six-sigma limiting magnitude')
plt.ylabel('Number of CCD-visits')
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6607: RuntimeWarning: All-NaN slice encountered
#   xmin = min(xmin, np.nanmin(xi))
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6608: RuntimeWarning: All-NaN slice encountered
#   xmax = max(xmax, np.nanmax(xi))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [34], in <cell line: 3>()
#       1 plt.figure(figsize=(12,8))
#       3 for band, color in zip( bandList, colorList):
# ----> 4     plt.hist(dflim.loc[dflim['filterName'] == band,'maglim6'],color=color,histtype='step',label=band)
#       5 plt.legend()
#       6 plt.xlabel('Six-sigma limiting magnitude')
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/pyplot.py:2602, in hist(x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, data, **kwargs)
#    2596 @_copy_docstring_and_deprecators(Axes.hist)
#    2597 def hist(
#    2598         x, bins=None, range=None, density=False, weights=None,
#    2599         cumulative=False, bottom=None, histtype='bar', align='mid',
#    2600         orientation='vertical', rwidth=None, log=False, color=None,
#    2601         label=None, stacked=False, *, data=None, **kwargs):
# -> 2602     return gca().hist(
#    2603         x, bins=bins, range=range, density=density, weights=weights,
#    2604         cumulative=cumulative, bottom=bottom, histtype=histtype,
#    2605         align=align, orientation=orientation, rwidth=rwidth, log=log,
#    2606         color=color, label=label, stacked=stacked,
#    2607         **({"data": data} if data is not None else {}), **kwargs)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/__init__.py:1412, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1409 @functools.wraps(func)
#    1410 def inner(ax, *args, data=None, **kwargs):
#    1411     if data is None:
# -> 1412         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1414     bound = new_sig.bind(ax, *args, **kwargs)
#    1415     auto_label = (bound.arguments.get(label_namer)
#    1416                   or bound.kwargs.get(label_namer))
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_axes.py:6635, in Axes.hist(self, x, bins, range, density, weights, cumulative, bottom, histtype, align, orientation, rwidth, log, color, label, stacked, **kwargs)
#    6631 # Loop through datasets
#    6632 for i in range(nx):
#    6633     # this will automatically overwrite bins,
#    6634     # so that each histogram uses the same bins
# -> 6635     m, bins = np.histogram(x[i], bins, weights=w[i], **hist_kwargs)
#    6636     tops.append(m)
#    6637 tops = np.array(tops, float)  # causes problems later if it's an int
#
# File <__array_function__ internals>:5, in histogram(*args, **kwargs)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/numpy/lib/histograms.py:793, in histogram(a, bins, range, normed, weights, density)
#     681 r"""
#     682 Compute the histogram of a dataset.
#     683
#    (...)
#     789
#     790 """
#     791 a, weights = _ravel_and_check_weights(a, weights)
# --> 793 bin_edges, uniform_bins = _get_bin_edges(a, bins, range, weights)
#     795 # Histogram is an integer or a float array depending on the weights.
#     796 if weights is None:
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/numpy/lib/histograms.py:426, in _get_bin_edges(a, bins, range, weights)
#     423     if n_equal_bins < 1:
#     424         raise ValueError('`bins` must be positive, when an integer')
# --> 426     first_edge, last_edge = _get_outer_edges(a, range)
#     428 elif np.ndim(bins) == 1:
#     429     bin_edges = np.asarray(bins)
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/numpy/lib/histograms.py:323, in _get_outer_edges(a, range)
#     321     first_edge, last_edge = a.min(), a.max()
#     322     if not (np.isfinite(first_edge) and np.isfinite(last_edge)):
# --> 323         raise ValueError(
#     324             "autodetected range of [{}, {}] is not finite".format(first_edge, last_edge))
#     326 # expand empty range to avoid divide by zero
#     327 if first_edge == last_edge:
#
# ValueError: autodetected range of [nan, nan] is not finite

# %%
plt.figure(figsize=(12,8))

for band, color in zip( bandList, colorList):
    wband = goodSrc['filterName'] == band
    plt.errorbar(goodSrc.loc[wband,'snr'],
                 np.abs(goodSrc.loc[wband,'psFlux']),
                 goodSrc.loc[wband,'psFluxErr'],
                 color=color,label=band,linestyle='none',fmt='o')
plt.legend()
plt.xlabel('SNR')
plt.ylabel('abs(psFlux)')
plt.xlim(4,10)
plt.ylim(0,500)
# Out:
# (0.0, 500.0)

# %%
plt.scatter(pd.Series(maglims5).values,pd.Series(maglims6).values)

# %% [markdown]
# Determine the 25th and 75th percentile limiting magnitudes by filter:

# %%
p25_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,25))
median_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,50))
p75_limmag = dflim.groupby('filterName').agg(lambda x: np.nanpercentile(x,75))

# %% [markdown]
# Plot per-filter completeness along with the limiting magnitudes and the required completeness:

# %%
plt.figure(figsize=(12, 12))

colorList = ['C2', 'C1', 'C3', 'C5', 'k']


for  band, color in zip( bandList, colorList):
    plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
    plt.axvline(median_limmag.loc[band,'maglim6'],color=color,ls=':')
    plt.axvspan(p25_limmag.loc[band,'maglim6'],p75_limmag.loc[band,'maglim6'],facecolor=color,alpha=0.2,edgecolor='none')

plt.axhline(.9, ls='--', color='0.75')#, label='90%')
plt.legend(loc='lower left')
plt.xlabel('Injected magnitude')
plt.ylabel('Fractional completeness')
# Out:
# /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/matplotlib/axes/_base.py:2480: UserWarning: Warning: converting a masked element to nan.
#   xys = np.asarray(xys)
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'r'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [97], in <cell line: 6>()
#       6 for  band, color in zip( bandList, colorList):
#       7     plt.errorbar(bins[0:-1], completeness_byband[band], completeness_err_byband[band], color=color,label=band)
# ----> 8     plt.axvline(median_limmag.loc[band,'maglim6'],color=color,ls=':')
#       9     plt.axvspan(p25_limmag.loc[band,'maglim6'],p75_limmag.loc[band,'maglim6'],facecolor=color,alpha=0.2,edgecolor='none')
#      11 plt.axhline(.9, ls='--', color='0.75')#, label='90%')
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexing.py:960, in _LocationIndexer.__getitem__(self, key)
#     958     key = tuple(com.apply_if_callable(x, self.obj) for x in key)
#     959     if self._is_scalar_access(key):
# --> 960         return self.obj._get_value(*key, takeable=self._takeable)
#     961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/frame.py:3622, in DataFrame._get_value(self, index, col, takeable)
#    3616 engine = self.index._engine
#    3618 if not isinstance(self.index, MultiIndex):
#    3619     # CategoricalIndex: Trying to use the engine fastpath may give incorrect
#    3620     #  results if our categories are integers that dont match our codes
#    3621     # IntervalIndex: IntervalTree has no get_loc
# -> 3622     row = self.index.get_loc(index)
#    3623     return series._values[row]
#    3625 # For MultiIndex going through engine effectively restricts us to
#    3626 #  same-length tuples; see test_get_set_value_no_partial_indexing
#
# File /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'r'
# > /opt/lsst/software/stack/conda/miniconda3-py38_4.9.2/envs/lsst-scipipe-4.1.0/lib/python3.10/site-packages/pandas/core/indexes/base.py(3623)get_loc()
#    3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
# -> 3623                 raise KeyError(key) from err
#    3624             except TypeError:
#    3625                 # If we have a listlike key, _check_indexing_error will raise
# ipdb>  q

# %% [markdown]
# So we are below the required 90% completeness level at 6 sigma in all bands: this need further investigation.  See DM-31388.
